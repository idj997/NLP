# %% [markdown]
# # NLP Assignment 1 (40% of grade): Sentiment Analysis from Tweets
#
# This coursework will involve you implementing functions for a text classifier, which you will train to identify the **sentiment expressed in a text** in a dataset of approx. 27,000 entries, which will be split into a 80%/20% training/test split.
#
# In this template you are given the basis for that implementation, though some of the functions are missing, which you have to fill in.
#
# Follow the instructions file **NLP_Assignment_1_Instructions.pdf** for details of each question - the outline of what needs to be achieved for each question is as below.
#
# You must submit all **ipython notebooks and extra resources you need to run the code if you've added them** in the code submission, and a **2 page report (pdf)** in the report submission on QMPlus where you report your methods and findings according to the instructions file for each question.

# %%
import csv                        
from sklearn.svm import LinearSVC
# !pip install nltk
import nltk
from nltk.classify import SklearnClassifier
from sklearn.pipeline import Pipeline
from sklearn.metrics import precision_recall_fscore_support # to report on precision and recall
import numpy as np
# Out:
# Requirement already satisfied: nltk in /opt/conda/lib/python3.10/site-packages (3.8.1)
# Requirement already satisfied: click in /opt/conda/lib/python3.10/site-packages (from nltk) (8.1.7)
# Requirement already satisfied: joblib in /opt/conda/lib/python3.10/site-packages (from nltk) (1.3.2)
# Requirement already satisfied: regex>=2021.8.3 in /opt/conda/lib/python3.10/site-packages (from nltk) (2023.10.3)
# Requirement already satisfied: tqdm in /opt/conda/lib/python3.10/site-packages (from nltk) (4.66.1)

# %%
def load_data(path):
    """Load data from a tab-separated file and append it to raw_data."""
    with open(path) as f:
        reader = csv.reader(f, delimiter='\t')
        for line in reader:
            if line[0] == "Id":  # skip header
                continue
            (label, text) = parse_data_line(line)
            raw_data.append((text, label))

def split_and_preprocess_data(percentage):
    """Split the data between train_data and test_data according to the percentage
    and performs the preprocessing."""
    num_samples = len(raw_data)
    num_training_samples = int((percentage * num_samples))
    for (text, label) in raw_data[:num_training_samples]:
        train_data.append((to_feature_vector(pre_process(text)),label))
    for (text, label) in raw_data[num_training_samples:]:
        test_data.append((to_feature_vector(pre_process(text)),label))

# %% [markdown]
# # Question 1: Input and Basic preprocessing (10 marks)

# %%
def parse_data_line(data_line):
# Should return a tuple of the label as just positive or negative and the statement
# e.g. (label, statement)
    label=data_line[1] #Store the label accross each statement in label array
    statement=data_line[2] #Store the statement in staement array
    return (label, statement) #Return label and statement

# %%
import re
# Input: a string of one statement
# A global dictionary of features
def pre_process(text):
    # Should return a list of tokens
    # DESCRIBE YOUR METHOD IN WORDS
    text = re.sub(r"(\w)([.,;:!?'\"”\)])", r"\1 \2", text) # separates punctuation at ends of strings
    text = re.sub(r"([.,;:!?'\"“\(\)])(\w)", r"\1 \2", text) # separates punctuation at beginning of strings
    tokens = re.split(r"\s+",text)
    # normalisation - only by lower casing
    tokens = [t.lower() for t in tokens]
    return tokens

# %% [markdown]
# # Question 2: Basic Feature Extraction (20 marks)

# %%
global_feature_dict = {}
def to_feature_vector(tokens):
    # Should return a dictionary containing features as keys, and weights as values
    # DESCRIBE YOUR METHOD IN WORDS
    feature_vector = {}
    for token in tokens:
        # Update the global feature dictionary
        global_feature_dict[token] = 0
        # Use binary feature values (1 if the feature is present, 0 otherwise)1
        feature_vector[token] = 1     
    return feature_vector

# %%
# TRAINING AND VALIDATING OUR CLASSIFIER
def train_classifier(data):
    print("Training Classifier...")
    pipeline =  Pipeline([('svc', LinearSVC(dual = 'auto'))])
    return SklearnClassifier(pipeline).train(data)

# %% [markdown]
# # Question 3: Cross-validation (20 marks)

# %%
from sklearn.metrics import precision_recall_fscore_support, accuracy_score
from sklearn.model_selection import KFold
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report

def cross_validate(dataset, folds):
    
    results = []
    fold_size = int(len(dataset) / folds)
    
    # Split the data into features and labels
    features = [data[0] for data in dataset]
    labels = [data[1] for data in dataset]

    # Use KFold to split the data into training and test sets for each fold
    kf = KFold(n_splits=folds, shuffle=True, random_state=50)

    for train_index, test_index in kf.split(features):
        # Split the data into training and test sets for this fold
        train_data, test_data = [features[i] for i in train_index], [features[i] for i in test_index]
        train_true, test_true = [labels[i] for i in train_index], [labels[i] for i in test_index]
        
        # Train the classifier on the training data
        classifier = train_classifier(list(zip(train_data, train_true)))

        # Predict labels on the test data
        predicted_labels = predict_labels(test_data, classifier)

        # Calculate evaluation metrics for this fold
        precision, recall, f1_score, _ = precision_recall_fscore_support(test_true, predicted_labels, average='weighted')
        accuracy = accuracy_score(test_true, predicted_labels)

        # Store the results for this fold
        results.append({
            'precision': precision,
            'recall': recall,
            'f1_score': f1_score,
            'accuracy': accuracy
        })

        print("Fold start on items %d - %d - %d - %d" % (train_index[0],train_index[-1],test_index[0], test_index[-1]))
        print("Precision: %.4f, Recall: %.4f, F1 Score: %.4f, Accuracy: %.4f" % (precision, recall, f1_score, accuracy))

    # Calculate average scores across all folds
    cv_results = {
        'precision': sum(result['precision'] for result in results) / len(results),
        'recall': sum(result['recall'] for result in results) / len(results),
        'f1_score': sum(result['f1_score'] for result in results) / len(results),
        'accuracy': sum(result['accuracy'] for result in results) / len(results),
    }

    print(classification_report(test_true,predicted_labels,labels = ['positive','negative']))

    print("Average Scores Across Folds:")
    print("Precision: %.4f, Recall: %.4f, F1 Score: %.4f, Accuracy: %.4f" % (cv_results['precision'], cv_results['recall'], cv_results['f1_score'], cv_results['accuracy']))

    return cv_results

# %%
# PREDICTING LABELS GIVEN A CLASSIFIER

def predict_labels(samples, classifier):
    """Assuming preprocessed samples, return their predicted labels from the classifier model."""
    return classifier.classify_many(samples)

def predict_label_from_raw(sample, classifier):
    """Assuming raw text, return its predicted label from the classifier model."""
    return classifier.classify(to_feature_vector(preProcess(reviewSample)))

# %%
# MAIN

# loading reviews
# initialize global lists that will be appended to by the methods below
raw_data = []          # the filtered data from the dataset file
train_data = []        # the pre-processed training data as a percentage of the total dataset
test_data = []         # the pre-processed test data as a percentage of the total dataset


# references to the data files
data_file_path = 'sentiment-dataset.tsv'

# Do the actual stuff (i.e. call the functions we've made)
# We parse the dataset and put it in a raw data list
print("Now %d rawData, %d trainData, %d testData" % (len(raw_data), len(train_data), len(test_data)),
      "Preparing the dataset...",sep='\n')

load_data(data_file_path) 

# We split the raw dataset into a set of training data and a set of test data (80/20)
# You do the cross validation on the 80% (training data)
# We print the number of training samples and the number of features before the split
print("Now %d rawData, %d trainData, %d testData" % (len(raw_data), len(train_data), len(test_data)),
      "Preparing training and test data...",sep='\n')

split_and_preprocess_data(0.8)

# We print the number of training samples and the number of features after the split
print("After split, %d rawData, %d trainData, %d testData" % (len(raw_data), len(train_data), len(test_data)),
      "Training Samples: ", len(train_data), "Features: ", len(global_feature_dict), sep='\n')
# Out:
# Now 0 rawData, 0 trainData, 0 testData
# Preparing the dataset...
# Now 33540 rawData, 0 trainData, 0 testData
# Preparing training and test data...
# After split, 33540 rawData, 26832 trainData, 6708 testData
# Training Samples:
# 26832
# Features:
# 64640

# %%
cross_validate(train_data, 10)  # will work and output overall performance of p, r, f-score when cv implemented
# Out:
# Training Classifier...
# Fold start on items 0 - 26831 - 12 - 26820
# Precision: 0.8504, Recall: 0.8506, F1 Score: 0.8505, Accuracy: 0.8506
# Training Classifier...
# Fold start on items 0 - 26830 - 18 - 26831
# Precision: 0.8507, Recall: 0.8517, F1 Score: 0.8511, Accuracy: 0.8517
# Training Classifier...
# Fold start on items 0 - 26831 - 1 - 26826
# Precision: 0.8341, Recall: 0.8360, F1 Score: 0.8345, Accuracy: 0.8360
# Training Classifier...
# Fold start on items 0 - 26831 - 3 - 26821
# Precision: 0.8542, Recall: 0.8558, F1 Score: 0.8544, Accuracy: 0.8558
# Training Classifier...
# Fold start on items 0 - 26831 - 19 - 26824
# Precision: 0.8454, Recall: 0.8468, F1 Score: 0.8457, Accuracy: 0.8468
# Training Classifier...
# Fold start on items 0 - 26831 - 2 - 26809
# Precision: 0.8580, Recall: 0.8591, F1 Score: 0.8584, Accuracy: 0.8591
# Training Classifier...
# Fold start on items 1 - 26831 - 0 - 26817
# Precision: 0.8541, Recall: 0.8550, F1 Score: 0.8544, Accuracy: 0.8550
# Training Classifier...
# Fold start on items 0 - 26831 - 5 - 26829
# Precision: 0.8566, Recall: 0.8580, F1 Score: 0.8567, Accuracy: 0.8580
# Training Classifier...
# Fold start on items 0 - 26831 - 7 - 26810
# Precision: 0.8443, Recall: 0.8446, F1 Score: 0.8444, Accuracy: 0.8446
# Training Classifier...
# Fold start on items 0 - 26831 - 34 - 26830
# Precision: 0.8614, Recall: 0.8625, F1 Score: 0.8617, Accuracy: 0.8625
#               precision    recall  f1-score   support
#
#     positive       0.88      0.91      0.90      1737
#     negative       0.82      0.78      0.80       946
#
#     accuracy                           0.86      2683
#    macro avg       0.85      0.84      0.85      2683
# weighted avg       0.86      0.86      0.86      2683
#
# Average Scores Across Folds:
# Precision: 0.8509, Recall: 0.8520, F1 Score: 0.8512, Accuracy: 0.8520
# {'precision': 0.8509151694430006,
#  'recall': 0.8520051319424116,
#  'f1_score': 0.8511889761622781,
#  'accuracy': 0.8520051319424116}

# %% [markdown]
# # Question 4: Error Analysis (20 marks)

# %%
from sklearn import metrics
import matplotlib.pyplot as plt
# a function to make the confusion matrix readable and pretty
def confusion_matrix_heatmap(y_test, preds, labels):
    """Function to plot a confusion matrix"""
    # pass labels to the confusion matrix function to ensure right order
    # cm = metrics.confusion_matrix(y_test, preds, labels)
    cm = metrics.confusion_matrix(y_test, preds, labels=labels)
    fig = plt.figure(figsize=(10,10))
    ax = fig.add_subplot(111)
    cax = ax.matshow(cm)
    plt.title('Confusion matrix of the classifier')
    fig.colorbar(cax)
    ax.set_xticks(np.arange(len(labels)))
    ax.set_yticks(np.arange(len(labels)))
    ax.set_xticklabels( labels, rotation=45)
    ax.set_yticklabels( labels)

    for i in range(len(cm)):
        for j in range(len(cm)):
            text = ax.text(j, i, cm[i, j],
                           ha="center", va="center", color="w")

    plt.xlabel('Predicted')
    plt.ylabel('True')
    
    # fix for mpl bug that cuts off top/bottom of seaborn viz:
    b, t = plt.ylim() # discover the values for bottom and top
    b += 0.5 # Add 0.5 to the bottom
    t -= 0.5 # Subtract 0.5 from the top
    plt.ylim(b, t) # update the ylim(bottom, top) values
    plt.show() # ta-da!
    plt.show()

# %%
kf = KFold(n_splits=10, shuffle=False)
features = [data[0] for data in train_data]
labels = [data[1] for data in train_data]
for train_index, test_index in kf.split(features):
    # Split the data into training and test sets for this fold
    X_train1, X_test1 = [features[i] for i in train_index], [features[i] for i in test_index]
    y_train1, y_test1 = [labels[i] for i in train_index], [labels[i] for i in test_index]
    #Train the classifier on the training data
    classifier = train_classifier(list(zip(X_train1, y_train1)))
    # Predict labels on the test data
    predicted_labels = predict_labels(X_test1, classifier)
    confusion_matrix_heatmap(y_test1,predicted_labels,['positive','negative'])
    #Breaking the loop as we need to plot confusion matrix only on first fold
    break
print(classification_report(y_test1,predicted_labels,labels = ['positive','negative']))
# Out:
# Training Classifier...
#               precision    recall  f1-score   support
#
#     positive       0.88      0.92      0.90      1866
#     negative       0.79      0.72      0.75       818
#
#     accuracy                           0.86      2684
#    macro avg       0.84      0.82      0.83      2684
# weighted avg       0.85      0.86      0.85      2684

# %%
tru_label =  [label for text, label in test_data]
# print(predicted_labels)
for index, value in enumerate(tru_label):
    if predicted_labels[index] != value:
        print('FALSE prediction FOR {2} (prediction = {1}):\n {0}\n'.format(test_data[index][0], predicted_labels[index], value))
        print('*'*50)
        print()
        continue
# Out:
# FALSE prediction FOR positive (prediction = negative):
#  {'i': 1, 'may': 1, 'be': 1, 'in': 1, 'the': 1, 'minority': 1, 'here': 1, ',': 1, 'but': 1, 'feel': 1, 'like': 1, 'george': 1, 'harrison': 1, 'pulled': 1, 'off': 1, '\\""': 1, 'full': 1, 'hobo\\""': 1, 'look': 1, 'better': 1, 'than': 1, 'john': 1, 'lennon': 1, '.': 1}
#
# **************************************************
#
# FALSE prediction FOR negative (prediction = positive):
#  {'tony': 1, 'blair': 1, 'said': 1, "'": 1, 'god': 1, 'will': 1, 'judge': 1, 'me': 1, 'over': 1, 'iraq': 1, '.': 1, 'here': 1, 's': 1, 'another': 1, 'biblical': 1, 'truism': 1, ':': 1, 'you': 1, '[we]': 1, 'reap': 1, 'what': 1, 'sow': 1, ".'": 1, 'https': 1, '://t': 1, 'co/9e4vpntozd': 1}
#
# **************************************************
#
# FALSE prediction FOR positive (prediction = negative):
#  {'i': 1, 'liked': 1, 'a': 1, '@youtube': 1, 'video': 1, 'http': 1, '://t': 1, '.': 1, 'co/pemh98r86t': 1, 'sen': 1, 'bernie': 1, 'sanders': 1, ':': 1, 'what': 1, 'would': 1, 'you': 1, 'do': 1, 'as': 1, 'president': 1, '?': 1, '1st': 1, 'campaign': 1, 'interview': 1, '-': 1, 'ed': 1}
#
# **************************************************
#
# FALSE prediction FOR positive (prediction = negative):
#  {'good': 1, 'morning': 1, 'neighbors': 1, '...': 1, 'tomorrow': 1, 'is': 1, 'national': 1, 'hot': 1, 'dog': 1, 'day': 1, '.': 1, 'here': 1, 'are': 1, 'some': 1, 'fun': 1, 'facts': 1, 'about': 1, 'dogs': 1, 'it': 1, 'an': 1, 'http': 1, '://t': 1, 'co/fd9mkllnjf': 1}
#
# **************************************************
#
# FALSE prediction FOR negative (prediction = positive):
#  {'nothing': 1, 'quite': 1, 'worked': 1, 'out': 1, 'for': 1, 'fidel': 1, 'castro': 1, ',': 1, 'good': 1, 'on': 1, 'paper': 1, 'terrible': 1, 'in': 1, 'real': 1, 'life': 1, '.': 1, 'not': 1, 'even': 1, 'his': 1, 'funeral': 1, 'as…': 1, 'https': 1, '://t': 1, 'co/6ourpeapjc': 1}
#
# **************************************************
#
# FALSE prediction FOR positive (prediction = negative):
#  {'@demigodv4to': 1, 'ohh': 1, ':': 1, 'd': 1, 'i': 1, 'just': 1, 'came': 1, 'back': 1, 'from': 1, 'melaka': 1, 'will': 1, 'go': 1, 'to': 1, 'sepang': 1, 'tomorrow': 1, '-.-': 1}
#
# **************************************************
#
# FALSE prediction FOR positive (prediction = negative):
#  {'its': 1, 'gucci': 1, 'tho': 1, '....': 1, 'i': 1, 'went': 1, 'from': 1, 'sleeping': 1, 'under': 1, 'cars': 1, 'to': 1, 'buying': 1, 'my': 1, '2nd': 1, 'crib': 1, '.': 1, 'thanks': 1, '4': 1, 'the': 1, 'push': 1}
#
# **************************************************
#
# FALSE prediction FOR positive (prediction = negative):
#  {'i': 1, "'": 1, 'll': 1, 'be': 1, 'at': 1, 'the': 1, 'donald': 1, 'trump': 1, 'rally': 1, 'next': 1, 'monday': 1, 'aac': 1, '.': 1}
#
# **************************************************
#
# FALSE prediction FOR negative (prediction = positive):
#  {'ben': 1, 'carson': 1, 'worth': 1, '$26m': 1, '.': 1, 'like': 1, 'how': 1, 'he': 1, 'is': 1, 'a': 1, 'fucking': 1, 'idiot': 1, 'even': 1, 'for': 1, 'brain': 1, 'surgeon': 1}
#
# **************************************************
#
# FALSE prediction FOR positive (prediction = negative):
#  {'leonard': 1, 'cohen': 1, 'is': 1, 'also': 1, 'the': 1, 'most': 1, 'compelling': 1, 'gnostic': 1, 'philosopher': 1}
#
# **************************************************
#
# FALSE prediction FOR negative (prediction = positive):
#  {'kim': 1, 'davis': 1, ',': 1, 'ky': 1, 'clerk': 1, 'blocking': 1, 'gay': 1, 'marriage': 1, 'held': 1, 'in': 1, 'cmpt': 1, '.': 1, 'a': 1, 'state': 1, 'employee': 1, '&amp': 1, ';': 1, 'broke': 1, 'the': 1, 'law': 1, 'have': 1, 'fun': 1, 'prison': 1, 'may': 1, 'u': 1, 'find': 1, 'nice': 1, 'woman': 1, '!': 1}
#
# **************************************************
#
# FALSE prediction FOR positive (prediction = negative):
#  {'.@kingsroadrocks': 1, 'enjoy': 1, "'": 1, 'fun': 1, 'on': 1, 'the': 1, 'fly': 1, 'with': 1, '@orvisuk': 1, 'in': 1, 'green': 1, 'park': 1, '16th': 1, 'from': 1, '4-6pm': 1, '.': 1, 'obama': 1, 'is': 1, 'a': 1, 'fan': 1, '!': 1, 'http': 1, '://t': 1, 'co/ubdshfgoql': 1}
#
# **************************************************
#
# FALSE prediction FOR positive (prediction = negative):
#  {'@rajivmakhni': 1, '#motog': 1, 'the': 1, 'ever': 1, 'evolving': 1, 'moto': 1, 'g': 1, '3rd': 1, 'gen': 1, 'firmly': 1, 'stands': 1, 'out': 1, 'as': 1, 'a': 1, 'beauty': 1, 'with': 1, 'brain': 1, 'for': 1, 'gennext': 1, '.': 1, 'let': 1, "'": 1, 's': 1, 'swim': 1, 'it': 1, 'awhile': 1}
#
# **************************************************
#
# FALSE prediction FOR positive (prediction = negative):
#  {'other': 1, 'than': 1, 'lemon': 1, 'tea&lemonade': 1, '.': 1, 'coke': 1, '&pepsi': 1, 'are': 1, 'my': 1, '2nd': 1, 'favorites': 1, 'as': 1, 'unhealthy': 1, 'they': 1, ',': 1, 'i': 1, 'cant/wont': 1, 'stop': 1, 'drinking': 1, 'them': 1, "'": 1, 're': 1, 'just': 1, 'so': 1, 'good': 1}
#
# **************************************************
#
# FALSE prediction FOR negative (prediction = positive):
#  {'breaking': 1, 'news': 1, ':': 1, 'msm': 1, 'confused': 1, 'michael': 1, 'moore': 1, 'for': 1, 'hillary': 1, 'in': 1, 'story': 1, 'https': 1, '://t': 1, '.': 1, 'co/htf4rdrexh': 1}
#
# **************************************************
#
# FALSE prediction FOR negative (prediction = positive):
#  {'to': 1, '"': 1, 'deplorables': 1, 'there': 1, 'is': 1, 'something': 1, 'wrong': 1, 'with': 1, 'those': 1, 'qualities': 1, '!': 1, 'especially': 1, 'education': 1, 'and': 1, 'empathy': 1, '#notmypresident': 1, 'https': 1, '://t': 1, '.': 1, 'co/hx2rmxnbvt': 1}
#
# **************************************************
#
# FALSE prediction FOR positive (prediction = negative):
#  {'snoop': 1, 'dogg': 1, 'was': 1, 'one': 1, 'of': 1, 'the': 1, 'stars': 1, 'to': 1, 'support': 1, 'matt': 1, 'barnes': 1, 'charity': 1, 'football': 1, 'game': 1, 'in': 1, 'la': 1, 'on': 1, 'sunday': 1, 'https': 1, '://t': 1, '.': 1, 'co/hpdzhk8zzh': 1}
#
# **************************************************
#
# FALSE prediction FOR positive (prediction = negative):
#  {'rivers': 1, 'to': 1, 'gates': 1, ',': 1, 'for': 1, 'only': 1, 'the': 1, '3rd': 1, 'time': 1, 'this': 1, 'season': 1, '.': 1, 'keep': 1, 'it': 1, 'up': 1, 'chiefs': 1, 'fantasy': 1, 'teams': 1, 'need': 1, 'you': 1}
#
# **************************************************
#
# FALSE prediction FOR positive (prediction = negative):
#  {'i': 1, 'liked': 1, 'a': 1, '@youtube': 1, 'video': 1, 'https': 1, '://t': 1, '.': 1, 'co/2ajngvdis1': 1, 'channel': 1, '4': 1, '-': 1, 'david': 1, 'blaine': 1, 'above': 1, 'the': 1, 'below': 1, '(': 1, 'harmony': 1, 'korine': 1, 'film': 1, ')': 1}
#
# **************************************************
#
# FALSE prediction FOR negative (prediction = positive):
#  {'activists': 1, 'demand': 1, 'release': 1, 'of': 1, 'jharkhand': 1, 'tribal': 1, 'leader': 1, ':': 1, 'new': 1, 'delhi': 1, ',': 1, 'nov': 1, '1': 1, '(': 1, 'ians': 1, ')': 1, 'condemning': 1, 'the': 1, 'arrest': 1, 'woman': 1, 'trib': 1, '...': 1, 'http': 1, '://t': 1, '.': 1, 'co/lzlgb1nw': 1}
#
# **************************************************
#
# FALSE prediction FOR negative (prediction = positive):
#  {'scots': 1, 'why': 1, 'they': 1, 'think': 1, 'the': 1, 'approach': 1, 'may': 1, 'work': 1, ',': 1, 'but': 1, 'there': 1, 'are': 1, 'basic': 1, 'questions': 1, 'that': 1, 'can': 1, 'bluetooth/wifi/smoke-signal': 1, 'would': 1, 'be': 1, 'tory': 1, 'donors': 1, 'nee': 1}
#
# **************************************************
#
# FALSE prediction FOR negative (prediction = positive):
#  {'fyi': 1, 'this': 1, 'pic': 1, 'is': 1, 'actually': 1, 'from': 1, 'the': 1, 'charlie': 1, 'hebdo': 1, 'tragedy': 1, 'in': 1, 'january': 1, '.': 1, 'french': 1, 'police': 1, 'are': 1, 'advising': 1, 'people': 1, 'to': 1, 'not': 1, 'gather': 1, 'https': 1, '://t': 1, 'co/jj8upgrbny': 1}
#
# **************************************************
#
# FALSE prediction FOR positive (prediction = negative):
#  {'music': 1, 'and': 1, 'minecraft': 1, ',': 1, 'the': 1, 'best': 1, 'thing': 1, 'on': 1, 'a': 1, 'free': 1, 'friday': 1, '.': 1, '@msfairyviolet': 1, 'is': 1, 'streaming': 1, '!': 1, 'omg': 1, 'get': 1, 'in': 1, 'here': 1, 'http': 1, '://t': 1, 'co/pxgelwx4is': 1}
#
# **************************************************
#
# FALSE prediction FOR positive (prediction = negative):
#  {'tremendous': 1, 'rally': 1, 'by': 1, 'miesha': 1, 'tate': 1, 'to': 1, 'win': 1, 'armbar': 1, 'in': 1, 'the': 1, '3rd': 1, '.': 1, 'julie': 1, 'kedzie': 1, 'is': 1, 'a': 1, 'great': 1, 'ambassador': 1, 'for': 1, 'mma': 1, '+': 1, 'fought': 1, 'her': 1, 'a**': 1, 'off': 1, 'respect': 1}
#
# **************************************************
#
# FALSE prediction FOR negative (prediction = positive):
#  {'as': 1, 'chemtrails': 1, 'of': 1, 'poisonous': 1, 'aluminum': 1, 'dim': 1, 'out': 1, 'the': 1, 'sun': 1, ',': 1, 'monsanto': 1, 'unveils': 1, 'new': 1, 'patents': 1, 'on': 1, 'gm': 1, 'seeds': 1, 'tolerant': 1, 'to': 1, 'and': 1, 'sunlight': 1, 'deprivation': 1, '.': 1}
#
# **************************************************
#
# FALSE prediction FOR positive (prediction = negative):
#  {'the': 1, 'only': 1, 'thing': 1, 'that': 1, 'will': 1, 'be': 1, 'getting': 1, 'me': 1, 'through': 1, 'tomorrow': 1, 'is': 1, 'sam': 1, 'smith': 1, 'concert': 1}
#
# **************************************************
#
# FALSE prediction FOR positive (prediction = negative):
#  {'thank': 1, 'you': 1, 'god': 1, 'for': 1, 'allowing': 1, 'another': 1, 'episode': 1, 'of': 1, 'law': 1, '&amp': 1, ';': 1, 'order': 1, 'to': 1, 'be': 1, 'put': 1, 'on': 1, 'netflix': 1, '.': 1, 'tomorrow': 1, 'night': 1, 'will': 1, 'nothing': 1, 'but': 1, 'pancakes': 1, ',': 1, 'puppy': 1, 'svu': 1}
#
# **************************************************
#
# FALSE prediction FOR positive (prediction = negative):
#  {'has': 1, 'played': 1, 'with': 1, ':': 1, '-': 1, 'messi': 1, 'in': 1, 'argentina': 1, 'cr7': 1, 'madrid': 1, 'rooney': 1, 'mu': 1, 'and': 1, 'now': 1, 'zlatan': 1, 'at': 1, 'p$g': 1, '.': 1, 'simply': 1, 'di': 1, 'mar': 1}
#
# **************************************************
#
# FALSE prediction FOR positive (prediction = negative):
#  {'wow': 1, '!': 1, '@taylorswift13': 1, "'": 1, 's': 1, 'bad': 1, 'blood': 1, 'is': 1, '#1': 1, 'at': 1, 'pop': 1, 'radio': 1, 'for': 1, 'the': 1, '5th': 1, 'week': 1, '.': 1}
#
# **************************************************
#
# FALSE prediction FOR negative (prediction = positive):
#  {'i': 1, 'dont': 1, 'understand': 1, 'the': 1, 'obsession': 1, 'with': 1, 'sharknado': 1, '....': 1, 'watched': 1, 'first': 1, 'two': 1, 'and': 1, 'they': 1, 'sucked': 1, '.': 1, 'im': 1, 'sure': 1, '3rd': 1, 'one': 1, 'is': 1, 'just': 1, 'as': 1, 'bad': 1}
#
# **************************************************
#
# FALSE prediction FOR positive (prediction = negative):
#  {'off': 1, 'to': 1, 'see': 1, 'fantastic': 1, 'beasts': 1, 'this': 1, 'weekend': 1, '?': 1, 'put': 1, 'some': 1, 'fire': 1, 'in': 1, 'your': 1, 'cauldron': 1, 'with': 1, 'a': 1, 'magical': 1, 'bodega': 1, 'feast': 1, 'first': 1, '!…': 1, 'https': 1, '://t': 1, '.': 1, 'co/zfamiso3ye': 1}
#
# **************************************************
#
# FALSE prediction FOR negative (prediction = positive):
#  {'@morningmika': 1, 'what': 1, 'was': 1, 'the': 1, 'reason': 1, 'u': 1, 'did': 1, 'not': 1, 'ask': 1, 'questions': 1, 'in': 1, 'kerry': 1, 'interview': 1, 'sat': 1, 'silence': 1, 'when': 1, 'speak': 1, 'it': 1, 'is': 1, 'only': 1, 'to': 1, 'mock': 1, 'right': 1}
#
# **************************************************
#
# FALSE prediction FOR negative (prediction = positive):
#  {'why': 1, 'would': 1, 'putin': 1, 'want': 1, 'a': 1, 'recount': 1, '?': 1, 'if': 1, 'someone': 1, 'has': 1, 'fiddled': 1, 'the': 1, 'figures': 1, ',': 1, 'it': 1, 'will': 1, 'be': 1, 'him': 1, '.': 1, '@thexclass': 1}
#
# **************************************************
#
# FALSE prediction FOR positive (prediction = negative):
#  {'the': 1, 'only': 1, 'person': 1, 'who': 1, 'could': 1, 'put': 1, 'this': 1, 'country': 1, 'back': 1, 'together': 1, '&amp': 1, ';': 1, 'reinforce': 1, 'it': 1, 'as': 1, 'a': 1, 'secular': 1, 'state': 1, 'is': 1, 'donald': 1, 'trump': 1, 'https': 1, '://t': 1, '.': 1, 'co/ckujkeatpr': 1}
#
# **************************************************
#
# FALSE prediction FOR negative (prediction = positive):
#  {'goodnight': 1, ',': 1, 'irene': 1, '.': 1, 'al': 1, 'you': 1, 'are': 1, 'easily': 1, 'amused': 1, 'this': 1, 'club': 1, 'stinks': 1, 'i': 1, 'think': 1, 'that': 1, 'the': 1, 'brewers': 1, 'may': 1, 'upset': 1, 'apple': 1, 'cart': 1, 'and': 1, 'win': 1, 'nl': 1, 'pennant': 1}
#
# **************************************************
#
# FALSE prediction FOR negative (prediction = positive):
#  {'i': 1, 'haven': 1, "'": 1, 't': 1, 'seen': 1, 'my': 1, 'best': 1, 'friend': 1, 'since': 1, 'the': 1, 'cubs': 1, 'parade': 1, '☹️': 1, 'and': 1, 'we': 1, 'only': 1, 'live': 1, 'less': 1, 'than': 1, '5': 1, 'minutes': 1, 'away': 1, '.': 1, '😩': 1}
#
# **************************************************
#
# FALSE prediction FOR positive (prediction = negative):
#  {'@jackjackjohnson': 1, 'johnson': 1, ',': 1, 'i': 1, "'": 1, 'm': 1, 'meeting': 1, 'you': 1, 'in': 1, 'september': 1, 'at': 1, 'digi': 1, 'houston': 1, '!': 1, 'are': 1, 'as': 1, 'excited': 1, 'to': 1, 'meet': 1, 'me': 1, 'am': 1, '?': 1}
#
# **************************************************
#
# FALSE prediction FOR negative (prediction = positive):
#  {'please': 1, '!!!': 1, 'watch': 1, 'fox': 1, 'news': 1, '9pm': 1, 'central': 1, 'tonight': 1, '(': 1, 'friday': 1, ')': 1, 'to': 1, 'see': 1, 'what': 1, 'planned': 1, 'parenthood': 1, 'is': 1, 'doing': 1, 'with': 1, 'millions': 1, 'of': 1, 'our': 1, 'tax': 1, 'dollars': 1, '.': 1}
#
# **************************************************
#
# FALSE prediction FOR positive (prediction = negative):
#  {'@nestacks': 1, 'it': 1, 'will': 1, 'be': 1, 'good': 1, 'for': 1, 'hoop': 1, 'so': 1, 'get': 1, 'ready': 1, 'dec': 1, '.': 1, '25': 1, 'u': 1, 'kno': 1, 'we': 1, 'c': 1, 'lakers': 1, 'vs': 1, 'heat': 1}
#
# **************************************************
#
# FALSE prediction FOR positive (prediction = negative):
#  {'our': 1, 'last': 1, 'draw': 1, 'for': 1, 'an': 1, 'hd': 1, 'tv': 1, 'is': 1, 'today': 1, ',': 1, '24': 1, 'feb': 1, '.,': 1, 'at': 1, 'noon': 1, '.': 1, 'good': 1, 'luck': 1, 'everyone': 1, '!': 1, 'details': 1, 'to': 1, 'enter': 1, 'the': 1, '#pplhdtv': 1, 'comp': 1, ':': 1}
#
# **************************************************
#
# FALSE prediction FOR negative (prediction = positive):
#  {'renzi': 1, "'": 1, 's': 1, 'problem': 1, 'was': 1, 'he': 1, 'seen': 1, 'as': 1, 'merkel': 1, 'puppet': 1, '&': 1, 'did': 1, 'what': 1, 'told': 1, 'brussels': 1, 're': 1, 'the': 1, 'euro': 1, 'and': 1, 'immigration': 1, 'both': 1, 'hated': 1, 'by': 1, 'italians': 1}
#
# **************************************************
#
# FALSE prediction FOR negative (prediction = positive):
#  {'why': 1, 'won': 1, "'": 1, 't': 1, 'nbc': 1, ',': 1, 'cbs': 1, 'abc': 1, 'and': 1, 'cnn': 1, 'cover': 1, 'the': 1, 'breaking': 1, 'news': 1, 'in': 1, 'benghazi': 1, 'story': 1, '?': 1, 'information': 1, 'came': 1, 'out': 1, 'last': 1, 'tuesday': 1, ',...': 1, 'http': 1, '://t': 1, '.': 1, 'co/fexpsvft': 1}
#
# **************************************************
#
# FALSE prediction FOR negative (prediction = positive):
#  {'my': 1, 'amazon': 1, 'package': 1, 'was': 1, 'supposed': 1, 'to': 1, 'be': 1, 'delivered': 1, 'today': 1, 'by': 1, '8pm': 1, '.': 1, 'guess': 1, 'that': 1, 'means': 1, 'i': 1, "'": 1, 'll': 1, 'get': 1, 'it': 1, 'tomorrow': 1, 'before': 1, '?': 1}
#
# **************************************************
#
# FALSE prediction FOR positive (prediction = negative):
#  {'lol': 1, '!': 1, 'the': 1, 'sworn': 1, 'affidavit': 1, 'from': 1, 'former': 1, 'saints': 1, 'dc': 1, 'gregg': 1, 'williams': 1, 'that': 1, '@nfl': 1, 'presented': 1, 'to': 1, 'vilma': 1, 'was': 1, 'signed': 1, 'last': 1, 'friday': 1, '.': 1, '(': 1, 'via': 1, '@adamschefter': 1, ')': 1}
#
# **************************************************
#
# FALSE prediction FOR positive (prediction = negative):
#  {'or': 1, 'just': 1, 'start': 1, 'watching': 1, 'game': 1, 'of': 1, 'thrones': 1, 'and': 1, 'be': 1, 'like': 1, ',': 1, '"': 1, 'i': 1, "'": 1, 'll': 1, 'finish': 1, 'it': 1, 'tomorrow': 1, 'before': 1, '2': 1}
#
# **************************************************
#
# FALSE prediction FOR negative (prediction = positive):
#  {'jay-z': 1, 'stole': 1, 'bigs': 1, 'actual': 1, 'words': 1, 'damn': 1, 'near': 1, 'da': 1, '1st': 1, '8': 1, 'bars': 1, 'on': 1, '"': 1, 'i': 1, 'just': 1, 'wanna': 1, 'love': 1, 'you': 1, '(': 1, 'give': 1, 'it': 1, 'to': 1, 'me': 1, ')': 1, 'https': 1, '://t': 1, '.': 1, 'co/xss5q3alzy': 1}
#
# **************************************************
#
# FALSE prediction FOR negative (prediction = positive):
#  {'who': 1, 'the': 1, 'hell': 1, 'am': 1, 'i': 1, 'gonna': 1, 'pitch': 1, 'tomorrow': 1, '?': 1, 'david': 1, 'price': 1, 'only': 1, 'guy': 1, 'wanna': 1, 'go': 1, 'with': 1, 'but': 1, 'he': 1, 'is': 1, 'going': 1, 'against': 1, 'us': 1, '.': 1}
#
# **************************************************
#
# FALSE prediction FOR negative (prediction = positive):
#  {'didn': 1, "'": 1, 't': 1, 'get': 1, 'a': 1, 'chance': 1, 'to': 1, 'post': 1, 'this': 1, 'the': 1, 'other': 1, 'day': 1, '.': 1, 'goodbye': 1, 'ralph': 1, 'mcquarrie': 1, 'may': 1, 'you': 1, 'return': 1, 'as': 1, 'force': 1, 'ghost': 1, 'guide': 1, 'young': 1, 'artists': 1, '...': 1, '#starwars': 1}
#
# **************************************************
#
# FALSE prediction FOR negative (prediction = positive):
#  {'nigeria': 1, 'was': 1, 'promised': 1, 'to': 1, 'be': 1, 'rid': 1, 'of': 1, 'boko': 1, 'haram': 1, 'in': 1, '2': 1, 'months': 1, 'by': 1, 'pmb': 1, '.': 1, 'it': 1, 'seems': 1, 'a': 1, 'mere': 1, 'promise': 1, 'after': 1, 'all': 1, '.@apcnigeria': 1, 'https': 1, '://t': 1, 'co/ehwiyi6udg': 1}
#
# **************************************************
#
# FALSE prediction FOR negative (prediction = positive):
#  {'@stephengutowski': 1, 'iran': 1, 'may': 1, 'regret': 1, 'it': 1, '.': 1, 'but': 1, 'only': 1, 'if': 1, 'happens': 1, 'under': 1, 'a': 1, 'gop': 1, 'president': 1, 'after': 1, 'obama': 1, 'and': 1, 'kerry': 1, 'are': 1, 'gone': 1}
#
# **************************************************
#
# FALSE prediction FOR negative (prediction = positive):
#  {'i': 1, 'was': 1, 'finally': 1, 'warming': 1, 'up': 1, 'to': 1, 'a': 1, '3rd': 1, 'fight': 1, 'with': 1, 'tate': 1, ',': 1, 'and': 1, 'then': 1, 'the': 1, 'ufc': 1, 'goes': 1, 'throws': 1, 'holm-run': 1, 'ball': 1, 'rousey': 1, '.': 1, 'don': 1, "'": 1, 't': 1, 'get': 1, 'it': 1, '.....': 1}
#
# **************************************************
#
# FALSE prediction FOR negative (prediction = positive):
#  {'israel': 1, 'threatens': 1, 'int': 1, "'": 1, 'l': 1, 'criminal': 1, 'court': 1, 'with': 1, 'retribution': 1, 'https': 1, '://t': 1, '.': 1, 'co/sndjxor4yy': 1, '#gaza': 1, '#palestine': 1, '#israel': 1, '#bds': 1}
#
# **************************************************
#
# FALSE prediction FOR negative (prediction = positive):
#  {'north': 1, 'korea': 1, 'wants': 1, 'china': 1, 'to': 1, 'remove': 1, 'this': 1, 'video': 1, 'kim': 1, 'jong': 1, 'un': 1, ',': 1, 'barack': 1, 'obama': 1, 'vladamir…': 1, 'https': 1, '://t': 1, '.': 1, 'co/rlzvuqsd2s': 1, 'co/kvrsjwv2qt': 1}
#
# **************************************************
#
# FALSE prediction FOR negative (prediction = positive):
#  {'the': 1, '#real': 1, 'effect': 1, 'of': 1, '#fakenews': 1, 'on': 1, 'rabid': 1, 'right': 1, '!': 1, '#brexithttps': 1, '://t': 1, '.': 1, 'co/lm0vjiklrj': 1}
#
# **************************************************
#
# FALSE prediction FOR positive (prediction = negative):
#  {'#trumpland': 1, 'on': 1, '@showtime': 1, '...': 1, 'michael': 1, 'moore': 1, 'is': 1, 'a': 1, 'daring': 1, 'man': 1, '.': 1, '#lol': 1, '#trump': 1}
#
# **************************************************
#
# FALSE prediction FOR positive (prediction = negative):
#  {'@justinbieber': 1, 'im': 1, 'so': 1, 'excited': 1, 'even': 1, 'though': 1, 'i': 1, 'wont': 1, 'see': 1, 'you': 1, 'til': 1, 'novemeber': 1, '5th': 1, '.': 1, 'oiershdjkfwle': 1, 'good': 1, 'luck': 1, 'tonight': 1, ',': 1, 'kidrauhl': 1, '!': 1}
#
# **************************************************
#
# FALSE prediction FOR positive (prediction = negative):
#  {'it': 1, "'": 1, 's': 1, 'prince': 1, 'george': 1, '2nd': 1, 'birthday': 1, '!': 1, 'with': 1, 'the': 1, 'following': 1, 'hashtag': 1, 'you': 1, 'can': 1, 'congratulate': 1, 'little': 1, '.': 1, 'we': 1, 'wish': 1, 'his': 1, '...': 1, 'http': 1, '://t': 1, 'co/8xvgsi15mh': 1}
#
# **************************************************
#
# FALSE prediction FOR negative (prediction = positive):
#  {'people': 1, 'getting': 1, 'off': 1, 'caltrain': 1, 'at': 1, '4th': 1, 'and': 1, 'king': 1, 'for': 1, 'the': 1, '#sfgiants': 1, 'parade': 1, 'are': 1, 'already': 1, 'pretty': 1, 'wasted': 1, '...': 1, 'least': 1, 'they': 1, 'didn': 1, "'": 1, 't': 1, 'drive': 1, 'in': 1, 'i': 1, 'guess': 1, '.': 1}
#
# **************************************************
#
# FALSE prediction FOR positive (prediction = negative):
#  {'gotta': 1, 'put': 1, 'the': 1, 'nirvana': 1, 'shirts': 1, 'on': 1, 'hold': 1, 'until': 1, 'wednesday': 1, '.': 1, 'guess': 1, 'i': 1, "'": 1, 'll': 1, 'try': 1, 'to': 1, 'look': 1, 'decent': 1}
#
# **************************************************
#
# FALSE prediction FOR negative (prediction = positive):
#  {'the': 1, 'red': 1, 'sox': 1, 'have': 1, 'completely': 1, 'fallen': 1, 'apart': 1, 'here': 1, 'in': 1, '10th': 1}
#
# **************************************************
#
# FALSE prediction FOR negative (prediction = positive):
#  {'you': 1, 'may': 1, 'try': 1, 'to': 1, 'suffer': 1, 'for': 1, 'there': 1, 'is': 1, 'cast': 1, 'into': 1, 'the': 1, 'planned': 1, 'parenthood': 1, 'facility': 1, 'in': 1, 'your': 1, 'gifts': 1, ',': 1, 'are': 1, 'above': 1, 'every': 1, 'decision': 1, 'at': 1, 'work': 1, 'p': 1, '...': 1}
#
# **************************************************
#
# FALSE prediction FOR negative (prediction = positive):
#  {'statistically': 1, ',': 1, '"': 1, 'bad': 1, 'luck': 1, 'is': 1, 'just': 1, 'as': 1, 'valid': 1, 'a': 1, 'cause': 1, 'for': 1, 'the': 1, 'electoral': 1, 'college': 1, 'result': 1, 'anything': 1, 'else': 1}
#
# **************************************************
#
# FALSE prediction FOR positive (prediction = negative):
#  {'@thecivilwars': 1, 'just': 1, 'another': 1, 'reminder': 1, 'of': 1, 'my': 1, 'request': 1, 'for': 1, 'you': 1, 'guys': 1, 'to': 1, 'sing': 1, 'kingdom': 1, 'come': 1, 'on': 1, 'thursday': 1, '...': 1, 'and': 1, 'safe': 1, 'sound': 1, ';)': 1}
#
# **************************************************
#
# FALSE prediction FOR negative (prediction = positive):
#  {'get': 1, 'your': 1, 'news': 1, 'about': 1, 'the': 1, '#trumptransitionteam': 1, 'not': 1, 'from': 1, 'backstabbing': 1, 'commie': 1, 'liars': 1, 'at': 1, '@cnn': 1, '@cbs': 1, '@msnbc': 1, 'https': 1, '://t': 1, '.': 1, 'co/zfxwnidnpg': 1, 'enemies': 1, 'of': 1, 'usa': 1}
#
# **************************************************
#
# FALSE prediction FOR negative (prediction = positive):
#  {'rick': 1, 'perry': 1, 'needs': 1, 'to': 1, 'stop': 1, 'bragging': 1, 'about': 1, 'governing': 1, 'the': 1, '"': 1, '12th': 1, 'largest': 1, 'economy': 1, 'in': 1, 'world': 1, 'like': 1, 'texas': 1, 'has': 1, 'its': 1, 'own': 1, 'federal': 1, 'reserve': 1, 'system': 1, '.': 1}
#
# **************************************************
#
# FALSE prediction FOR negative (prediction = positive):
#  {'them': 1, 'is': 1, 'fake': 1, 'fans': 1, 'lmfao': 1, '.': 1, 'real': 1, 'frank': 1, 'ocean': 1, 'lowkwy': 1, 'ain': 1, "'": 1, 't': 1, 'shit': 1, 'or': 1, 'that': 1, 'just': 1, 'may': 1, 'be': 1, 'me': 1, 'https': 1, '://t': 1, 'co/ol8g3mvrjb': 1}
#
# **************************************************
#
# FALSE prediction FOR negative (prediction = positive):
#  {'and': 1, '@whytology': 1, 'article': 1, '3': 1, 'gives': 1, 'scotus': 1, 'no': 1, 'legislative': 1, 'powers': 1, 'the': 1, '10th': 1, 'amendment': 1, 'is': 1, 'clear': 1, '.': 1, '14th': 1, 'sec': 1, '5': 1, 'requires': 1, 'an': 1, 'act': 1, 'of': 1, 'congress': 1}
#
# **************************************************
#
# FALSE prediction FOR positive (prediction = negative):
#  {'@thewinningseat': 1, 'get': 1, 'the': 1, 'app': 1, '!': 1, 'saturday': 1, 'will': 1, 'be': 1, 'here': 1, 'before': 1, 'you': 1, 'know': 1, 'it': 1, 'store': 1, 'https': 1, '://t': 1, '.': 1, 'co/jkj2dkcgod': 1, 'google': 1, 'play': 1, 'co/dugakd2pnj': 1}
#
# **************************************************
#
# FALSE prediction FOR positive (prediction = negative):
#  {'i': 1, 'can': 1, "'": 1, 't': 1, 'wait': 1, 'to': 1, 'see': 1, 'ed': 1, 'sheeran': 1, 'on': 1, 'the': 1, '10th': 1, '!!!!!!!': 1}
#
# **************************************************
#
# FALSE prediction FOR positive (prediction = negative):
#  {'thursday': 1, 'night': 1, 'is': 1, 'reserved': 1, 'for': 1, 'comedys': 1, 'on': 1, 'nbc': 1, ',': 1, 'fx': 1, 'and': 1, 'tonight': 1, 'nfl': 1, 'network': 1, '.': 1}
#
# **************************************************
#
# FALSE prediction FOR positive (prediction = negative):
#  {'the': 1, 'sun': 1, 'starting': 1, 'coming': 1, 'out': 1, 'from': 1, 'underneath': 1, 'clouds': 1, 'and': 1, 'beautiful': 1, 'day': 1, 'by': 1, 'u2': 1, 'started': 1, 'playing': 1, 'on': 1, 'radio': 1, '.': 1, 'sometimes': 1, 'life': 1, 'just': 1, 'cooperates': 1}
#
# **************************************************
#
# FALSE prediction FOR negative (prediction = positive):
#  {'kerry': 1, 'now': 1, 'starts': 1, 'begging': 1, 'iran': 1, 'to': 1, 'release': 1, 'american': 1, 'hostages': 1, ',': 1, 'iranians': 1, 'laughing': 1, 'all': 1, 'the': 1, 'way': 1, 'bomb': 1, '.': 1, '#': 1, 'sunday': 1, 'morning': 1, 'futures': 1, '@foxnews': 1}
#
# **************************************************
#
# FALSE prediction FOR positive (prediction = negative):
#  {'heeeeey': 1, '@101wkqx': 1, 'and': 1, '@sabra': 1, ',': 1, 'i': 1, 'would': 1, 'love': 1, 'to': 1, 'see': 1, 'the': 1, 'great': 1, 'sir': 1, 'paul': 1, 'mccartney': 1, 'on': 1, 'friday': 1, 'at': 1, 'lolla': 1, '!!': 1, '#spreadtheworld': 1}
#
# **************************************************
#
# FALSE prediction FOR negative (prediction = positive):
#  {'@army1man1': 1, '@pocketcrow': 1, '@arknspreadthin': 1, '@gregabbott_tx': 1, 'so': 1, 'why': 1, 'are': 1, 'you': 1, 'trying': 1, 'to': 1, 'ban': 1, 'gay': 1, 'marriage': 1, 'and': 1, 'not': 1, 'divorce': 1, '?': 1}
#
# **************************************************
#
# FALSE prediction FOR negative (prediction = positive):
#  {'merkel': 1, "'": 1, 's': 1, 'germany': 1, 'could': 1, 'not': 1, 'crush': 1, 'europe': 1, 'with': 1, 'bombs': 1, 'muslims': 1, 'may': 1, 'be': 1, 'a': 1, 'better': 1, 'consideration': 1, 'david': 1, 'cameron': 1, 'http': 1, '://t': 1, '.': 1, 'co/qc0oyr4u0j': 1}
#
# **************************************************
#
# FALSE prediction FOR negative (prediction = positive):
#  {'@kendalldawn13': 1, 'it': 1, "'": 1, 's': 1, 'time': 1, 'to': 1, 'call': 1, 'in': 1, 'the': 1, 'cbb': 1, '...': 1, 'monday': 1, 'is': 1, 'going': 1, 'down': 1, '!': 1}
#
# **************************************************
#
# FALSE prediction FOR positive (prediction = negative):
#  {'beyonce': 1, 'sang': 1, 'the': 1, 'words': 1, 'we': 1, 'could': 1, 'never': 1, 'come': 1, 'up': 1, 'with': 1, '!': 1, '\\"': 1, 'best': 1, 'thing': 1, 'i': 1, 'had': 1, '.\\"': 1, 'didn': 1, "'": 1, 't': 1, 'give': 1, 'song': 1, 'a': 1, 'chance': 1, '@': 1, '1st': 1, ',': 1, 'but': 1, 'it': 1, 's': 1, 'growing': 1, 'on': 1, 'me': 1, '.': 1}
#
# **************************************************
#
# FALSE prediction FOR negative (prediction = positive):
#  {'@borismahogany': 1, 'the': 1, 'horsehoe': 1, 'theory': 1, 'and': 1, 'bell': 1, 'curve': 1, '.': 1, 'mmm': 1, 'this': 1, 'will': 1, 'put': 1, 'those': 1, 'alt-rightists': 1, 'to': 1, 'task': 1, 'boy': 1, 'howdy': 1}
#
# **************************************************
#
# FALSE prediction FOR positive (prediction = negative):
#  {'a': 1, 'phone': 1, 'isn': 1, "'": 1, 't': 1, 'just': 1, 'about': 1, 'specs': 1, ',': 1, 'its': 1, 'the': 1, 'experience': 1, '.': 1, 'this': 1, 'is': 1, 'where': 1, 'moto': 1, 'g': 1, '(': 1, '3rd': 1, 'gen': 1, ')': 1, 'excels': 1, '!': 1, 'http': 1, '://t': 1, 'co/v68fb21syy': 1, '#android': 1}
#
# **************************************************
#
# FALSE prediction FOR positive (prediction = negative):
#  {'extra': 1, 'zac': 1, 'brown': 1, 'band': 1, 'ticket': 1, 'for': 1, 'friday': 1, 'is': 1, 'anyone': 1, 'interested': 1, '!!!!': 1, '(': 1, 'you': 1, 'get': 1, 'to': 1, 'sit': 1, 'with': 1, 'me': 1, 'and': 1, 'my': 1, 'sisters': 1, ')': 1}
#
# **************************************************
#
# FALSE prediction FOR positive (prediction = negative):
#  {'@bbc6music': 1, '@maryannehobbs': 1, 'nirvana': 1, '.': 1, 'it': 1, 'just': 1, 'feels': 1, 'right': 1, 'happy': 1, 'sunday': 1, '!': 1, '#6hobbs': 1}
#
# **************************************************
#
# FALSE prediction FOR negative (prediction = positive):
#  {'@actoninstitute': 1, '"': 1, 'why': 1, 'won': 1, "'": 1, 't': 1, 'you': 1, 'evil': 1, 'leftists': 1, 'just': 1, 'consider': 1, 'that': 1, 'young': 1, 'children': 1, 'are': 1, 'good': 1, 'workers': 1, 'because': 1, 'they': 1, 're': 1, 'easier': 1, 'to': 1, 'manipulate': 1, '!"': 1}
#
# **************************************************
#
# FALSE prediction FOR positive (prediction = negative):
#  {'bam': 1, 'lifestyle': 1, 'nike': 1, "'": 1, 's': 1, 'online': 1, 'raffle': 1, 'system': 1, 'may': 1, 'have': 1, 'finally': 1, 'beaten': 1, 'the': 1, 'bots': 1, 'http': 1, '://t': 1, '.': 1, 'co/rfi03byigr': 1}
#
# **************************************************
#
# FALSE prediction FOR negative (prediction = positive):
#  {'@kingkc1': 1, 'what': 1, "'": 1, 's': 1, 'annoying': 1, 'is': 1, 'that': 1, 'the': 1, 'one': 1, 'i': 1, 'pre-ordered': 1, 'just': 1, 'came': 1, 'today': 1, '...': 1, 'steve': 1, 'jobs': 1, 'looted': 1, 'my': 1, 'card': 1, '.': 1}
#
# **************************************************
#
# FALSE prediction FOR negative (prediction = positive):
#  {'@apwestgarth': 1, 'in': 1, 'case': 1, 'you': 1, 'didn': 1, "'": 1, 't': 1, 'spot': 1, 'it': 1, ',': 1, 'greys': 1, 'anatomy': 1, 'is': 1, 'back': 1, 'next': 1, 'wednesday': 1, 'at': 1, '10': 1, 'on': 1, 'living': 1, '//': 1, '@stack72': 1}
#
# **************************************************
#
# FALSE prediction FOR negative (prediction = positive):
#  {'@chrislhayes': 1, '@michelle_888': 1, '#trumptransitionteam': 1, 'all': 1, 'with': 1, 'history': 1, 'of': 1, 'antisemitism': 1, 'and': 1, 'such': 1, '...': 1, 'https': 1, '://t': 1, '.': 1, 'co/bujest32ta': 1}
#
# **************************************************
#
# FALSE prediction FOR negative (prediction = positive):
#  {'hulk': 1, 'hogan': 1, 'won': 1, "'": 1, 't': 1, 'have': 1, 'a': 1, 'good': 1, 'day': 1, 'tomorrow': 1, 'when': 1, 'he': 1, 'realises': 1, 'everyone': 1, 'has': 1, 'been': 1, 'treating': 1, 'him': 1, 'like': 1, 'world': 1, 'class': 1, 'cunt': 1}
#
# **************************************************
#
# FALSE prediction FOR negative (prediction = positive):
#  {'@sesdsports': 1, ':': 1, 'according': 1, 'to': 1, 'reporters': 1, 'on': 1, 'the': 1, 'scene': 1, ',': 1, 'lions': 1, 'rookie': 1, 'rb': 1, 'mikel': 1, 'leshoure': 1, 'was': 1, 'carted': 1, 'off': 1, 'field': 1, 'today': 1, 'with': 1, 'a': 1, 'left': 1, 'leg': 1, 'injury': 1, '.': 1, 'sry': 1, 'bro': 1}
#
# **************************************************
#
# FALSE prediction FOR positive (prediction = negative):
#  {'you': 1, "'": 1, 're': 1, 'going': 1, 'to': 1, 'ban': 1, 'straight': 1, 'dvd': 1, 'disney': 1, 'movies': 1, '?': 1, '\\""': 1, 'aladdin': 1, '4': 1, ':': 1, 'jafar': 1, 'may': 1, 'need': 1, 'glasses\\""': 1, '1': 1, 'or': 1, '2': 1, 'umm': 1, '...': 1, 'hahahah': 1, '#familyguy': 1}
#
# **************************************************
#
# FALSE prediction FOR positive (prediction = negative):
#  {'big': 1, 'game': 1, 'for': 1, '@miamiheat': 1, 'tomorrow': 1, ',': 1, 'away': 1, 'vs': 1, 'the': 1, 'knicks': 1, 'at': 1, 'msg': 1, '.': 1, 'personally': 1, 'think': 1, 'will': 1, 'win': 1, '...': 1, 'first': 1, 'crowd': 1, 'sandy': 1, 'disaster': 1}
#
# **************************************************
#
# FALSE prediction FOR positive (prediction = negative):
#  {'@utahjazz': 1, 'i': 1, 'want': 1, 'to': 1, 'go': 1}
#
# **************************************************
#
# FALSE prediction FOR positive (prediction = negative):
#  {'guess': 1, 'who': 1, "'": 1, 's': 1, 'going': 1, 'to': 1, 'sit': 1, 'in': 1, 'a': 1, 'tub': 1, 'and': 1, 'listen': 1, 'fleetwood': 1, 'mac': 1, 'pretend': 1, 'tomorrow': 1, 'isn': 1, 't': 1, 'monday': 1, '?': 1, 'me': 1}
#
# **************************************************
#
# FALSE prediction FOR negative (prediction = positive):
#  {'heads': 1, 'up': 1, ':': 1, 'an': 1, 'important': 1, 'change': 1, 'to': 1, 'amazon': 1, 'prime': 1, 'effective': 1, 'august': 1, '1': 1, 'will': 1, 'limit': 1, 'how': 1, 'you': 1, 'can': 1, 'share': 1, 'free': 1, 'p': 1, '...': 1, 'http': 1, '://t': 1, '.': 1, 'co/bndstpovjq': 1, '@debtblag': 1}
#
# **************************************************
#
# FALSE prediction FOR positive (prediction = negative):
#  {'eric': 1, 'arc': 1, 'elliott': 1, 'may': 1, 'be': 1, 'the': 1, 'best': 1, 'rapper': 1, 'in': 1, 'flatbush': 1, 'zombies': 1, '.': 1}
#
# **************************************************
#
# FALSE prediction FOR negative (prediction = positive):
#  {'with': 1, 'james': 1, 'comey': 1, 'in': 1, 'office': 1, ',': 1, 'how': 1, 'could': 1, 'the': 1, 'us': 1, 'investigate': 1, 'russians': 1, '?': 1, '@fec': 1, '@cia': 1, '@senwarren': 1, '@kamalaharris…': 1, 'https': 1, '://t': 1, '.': 1, 'co/vx795careb': 1}
#
# **************************************************
#
# FALSE prediction FOR positive (prediction = negative):
#  {'@jaycyde': 1, 'there': 1, 'are': 1, 'a': 1, 'few': 1, 'winks': 1, 'in': 1, 'winter': 1, 'soldier': 1, 'and': 1, 'ant-man': 1, ',': 1, 'various': 1, 'iron': 1, 'mans': 1, '.': 1, 'largely': 1, 'though': 1, 'you': 1, 'may': 1, 'be': 1, 'right': 1}
#
# **************************************************
#
# FALSE prediction FOR positive (prediction = negative):
#  {'it': 1, "'": 1, 's': 1, 'friday': 1, 'before': 1, 'wppi': 1, '!': 1, 'who': 1, 'is': 1, 'going': 1, 'this': 1, 'year': 1, '?!': 1, 'i': 1, 'am': 1, '!!': 1, 'leave': 1, 'on': 1, 'sunday': 1, ',': 1, 'wanted': 1, 'to': 1, 'give': 1, 'out': 1, 'a': 1, 'fun': 1, '...': 1, 'http': 1, '://t': 1, '.': 1, 'co/ncwpsyd4': 1}
#
# **************************************************
#
# FALSE prediction FOR positive (prediction = negative):
#  {'@cineworld': 1, '#fantasticbeasts': 1, '#cheltenham': 1, '#datenight': 1, '#imax': 1, 'so': 1, 'excited': 1, 'to': 1, 'see': 1, 'this': 1, '!': 1, 'https': 1, '://t': 1, '.': 1, 'co/skiisdebm1': 1}
#
# **************************************************
#
# FALSE prediction FOR negative (prediction = positive):
#  {'@nymag': 1, '@ed_kilgore': 1, 'a': 1, 'better': 1, 'plan': 1, 'is': 1, 'just': 1, 'mass': 1, 'euthanasia': 1, '.': 1}
#
# **************************************************
#
# FALSE prediction FOR negative (prediction = positive):
#  {'i': 1, "'": 1, 'm': 1, 'going': 1, 'to': 1, 'fight': 1, 'justin': 1, 'tomorrow': 1, 'during': 1, 'lunch': 1, 'idc': 1, 'dc': 1}
#
# **************************************************
#
# FALSE prediction FOR positive (prediction = negative):
#  {'a': 1, 'whole': 1, 'monday': 1, 'and': 1, 'i': 1, 'can': 1, "'": 1, 't': 1, 'get': 1, 'rid': 1, 'of': 1, 'the': 1, 'chris': 1, 'brown': 1, 'songs': 1, 'doing': 1, 'replays': 1, 'in': 1, 'my': 1, 'mind': 1, '.': 1, 'for': 1, 'love': 1, 'breezy': 1, '*sigh*': 1, 'cc': 1, '@poshqra': 1}
#
# **************************************************
#
# FALSE prediction FOR positive (prediction = negative):
#  {'i': 1, 'can': 1, "'": 1, 't': 1, 'wait': 1, 'until': 1, 'tomorrow': 1, 'for': 1, 'all': 1, 'the': 1, 'memes': 1, 'about': 1, 'kanye': 1, 'west': 1, 'running': 1, 'president': 1, '!': 1, '#vmas': 1}
#
# **************************************************
#
# FALSE prediction FOR negative (prediction = positive):
#  {'@shockadelicaa': 1, 'just': 1, 'until': 1, 'the': 1, '17th': 1, 'or': 1, 'some': 1, 'shit': 1, '.': 1, 'i': 1, 'don': 1, "'": 1, 't': 1, 'want': 1, 'to': 1, 'see': 1, 'madonna': 1, 'spoilers': 1}
#
# **************************************************
#
# FALSE prediction FOR negative (prediction = positive):
#  {'sun': 1, 'newspaper': 1, 'disrespecting': 1, 'the': 1, 'war': 1, 'dead': 1, '?': 1, 'really': 1, 'labour': 1, 'woman': 1, 'what': 1, 'does': 1, 'your': 1, 'leader': 1, 'think': 1, 'though': 1, 'we': 1, 'know': 1, 'he': 1, 'respects': 1, 'ira': 1, '#bbcqt': 1}
#
# **************************************************
#
# FALSE prediction FOR positive (prediction = negative):
#  {'start': 1, 'your': 1, 'friday': 1, 'off': 1, 'the': 1, 'right': 1, 'way': 1, 'by': 1, 'watching': 1, 'john': 1, 'cena': 1, 'save': 1, 'day': 1, 'during': 1, 'an': 1, 'episode': 1, 'of': 1, 'scooby': 1, 'doo': 1, ':': 1, 'https': 1, '://t': 1, '.': 1, 'co/u7jqwsywbb': 1}
#
# **************************************************
#
# FALSE prediction FOR negative (prediction = positive):
#  {'sharknado': 1, 'may': 1, 'well': 1, 'be': 1, 'the': 1, 'flat': 1, 'out': 1, 'dumbest': 1, 'thing': 1, 'ever': 1, 'to': 1, 'occupy': 1, 'a': 1, 'tv': 1, 'screen': 1, '.': 1}
#
# **************************************************
#
# FALSE prediction FOR negative (prediction = positive):
#  {'nigeria': 1, 'needs': 1, 'gun': 1, 'control': 1, '@frscnigeria': 1, 'gaining': 1, 'approval': 1, 'to': 1, 'carry': 1, 'arms': 1, '!': 1, '@ngrsenate': 1, 'should': 1, 'reconsider': 1, 'this': 1, '..': 1, 'no': 1, 'good': 1, 'can': 1, 'come': 1, 'out': 1, 'of': 1, 'it': 1}
#
# **************************************************
#
# FALSE prediction FOR negative (prediction = positive):
#  {'#cjtfoir': 1, ':': 1, 'near': 1, '#mosul': 1, ',': 1, '6strikes': 1, 'engaged': 1, 'destroyed': 1, '6boats': 1, '4vehicles': 1, '3vbieds#mosuloffensive': 1, '#mosulop': 1, '#iraq#isis…': 1, 'https': 1, '://t': 1, '.': 1, 'co/colbpxcnri': 1}
#
# **************************************************
#
# FALSE prediction FOR negative (prediction = positive):
#  {'@dailykos': 1, '#thankyouobama': 1, 'for': 1, 'destroying': 1, 'the': 1, 'democratic': 1, 'party': 1, 'and': 1, 'your': 1, 'legacy': 1, 'within': 1, '100': 1, 'days': 1, 'of': 1, 'you': 1, 'leaving': 1, 'office': 1, 'https': 1, '://t': 1, '.': 1, 'co/qrh4usksip': 1}
#
# **************************************************
#
# FALSE prediction FOR negative (prediction = positive):
#  {'lord': 1, 'monckton': 1, ':': 1, 'the': 1, 'leftists': 1, 'system': 1, 'is': 1, 'political': 1, 'satanism': 1, 'https': 1, '://t': 1, '.': 1, 'co/rbxfrirmbl': 1}
#
# **************************************************
#
# FALSE prediction FOR positive (prediction = negative):
#  {'true': 1, 'blood': 1, 'tonight': 1, '!': 1, 'always': 1, 'the': 1, 'best': 1, 'night': 1, 'of': 1, 'week': 1, '.': 1}
#
# **************************************************
#
# FALSE prediction FOR positive (prediction = negative):
#  {'just': 1, 'bought': 1, 'my': 1, '"': 1, 'boruto': 1, '-': 1, 'naruto': 1, 'the': 1, 'movie': 1, 'ticket': 1, 'for': 1, 'october': 1, '10': 1, '!': 1, 'http': 1, '://t': 1, '.': 1, 'co/6h1kl0u4wb': 1}
#
# **************************************************
#
# FALSE prediction FOR positive (prediction = negative):
#  {'just': 1, 'did': 1, 'the': 1, 'math': 1, 'and': 1, 'realized': 1, 'that': 1, 'i': 1, 'get': 1, 'to': 1, 'see': 1, 'david': 1, 'price': 1, 'pitch': 1, 'live': 1, 'next': 1, 'sunday': 1, '.': 1, 'cool': 1, '!': 1, '#bluejays': 1}
#
# **************************************************
#
# FALSE prediction FOR negative (prediction = positive):
#  {'am': 1, 'i': 1, 'the': 1, 'only': 1, 'one': 1, 'who': 1, 'doesn': 1, "'": 1, 't': 1, 'care': 1, 'that': 1, 'floyd': 1, 'mayweather': 1, 'is': 1, 'fighting': 1, 'again': 1, 'on': 1, 'september': 1, '12th': 1, 'against': 1, 'andre': 1, 'berto': 1, '....': 1, 'http': 1, '://t': 1, '.': 1, 'co/jvydzh7ufo': 1}
#
# **************************************************
#
# FALSE prediction FOR positive (prediction = negative):
#  {'had': 1, 'no': 1, 'plans': 1, 'of': 1, 'seeing': 1, 'paper': 1, 'towns': 1, ',': 1, 'but': 1, 'love': 1, '@caradelevingne': 1, '.': 1, 'may': 1, 'look': 1, 'into': 1, 'it': 1}
#
# **************************************************
#
# FALSE prediction FOR negative (prediction = positive):
#  {'michael': 1, 'moore': 1, 'is': 1, 'gay': 1, 'https': 1, '://t': 1, '.': 1, 'co/ikdyozg5dr': 1}
#
# **************************************************
#
# FALSE prediction FOR negative (prediction = positive):
#  {'@novriltataki': 1, 'they': 1, 'tend': 1, 'to': 1, 'be': 1, 'leftists': 1, 'or': 1, 'at': 1, 'least': 1, 'interventionists': 1, 'so': 1, "'": 1, 're': 1, 'a': 1, 'bit': 1, 'of': 1, 'problem': 1}
#
# **************************************************
#
# FALSE prediction FOR positive (prediction = negative):
#  {'rick': 1, 'perry': 1, 'is': 1, 'amazing': 1, '.': 1, 'his': 1, 'speech': 1, 'was': 1, 'the': 1, 'best': 1, 'hands': 1, 'down': 1, '#perry2016': 1, 'https': 1, '://t': 1, 'co/97j8jie8te': 1}
#
# **************************************************
#
# FALSE prediction FOR positive (prediction = negative):
#  {'i': 1, 'was': 1, 'watching': 1, 'friday': 1, 'rn': 1, 'and': 1, 'ice': 1, 'cube': 1, 'uhh': 1, 'pretty': 1, 'good': 1, 'looking': 1, 'if': 1, 'you': 1, 'ask': 1, 'me': 1}
#
# **************************************************
#
# FALSE prediction FOR positive (prediction = negative):
#  {'mom': 1, ',': 1, 'can': 1, 'i': 1, 'miss': 1, 'a1': 1, 'on': 1, 'thursday': 1, '?': 1, 'if': 1, 'you': 1, 'love': 1, 'me': 1, "'": 1, 'll': 1, 'say': 1, 'yes': 1, '.': 1, '#hopefultweet': 1}
#
# **************************************************
#
# FALSE prediction FOR negative (prediction = positive):
#  {'do': 1, 'you': 1, 'ever': 1, 'just': 1, 'cry': 1, 'on': 1, 'a': 1, 'daily': 1, 'basis': 1, 'bc': 1, 'of': 1, 'how': 1, 'fat': 1, 'and': 1, 'ugly': 1, 'u': 1, 'are': 1, 'the': 1, 'fact': 1, 'that': 1, 'may': 1, 'never': 1, 'meet': 1, 'niall': 1, 'harry': 1, 'louis': 1, 'liam': 1, 'zayn': 1, 'hurts': 1}
#
# **************************************************
#
# FALSE prediction FOR positive (prediction = negative):
#  {'i': 1, 'think': 1, 'that': 1, 'having': 1, 'undertaker': 1, 'on': 1, 'monday': 1, 'night': 1, 'raw': 1, 'and': 1, 'in': 1, 'a': 1, 'feud': 1, 'with': 1, 'brock': 1, 'lesnar': 1, 'is': 1, 'best': 1, 'for': 1, 'business': 1, '!': 1, '#rawkansascity': 1, '#wwe': 1}
#
# **************************************************
#
# FALSE prediction FOR negative (prediction = positive):
#  {'@aarongleeman': 1, 'cubs': 1, 'fans': 1, 'still': 1, 'complaining': 1, 'that': 1, 'kris': 1, 'bryant': 1, 'didnt': 1, 'come': 1, 'up': 1, 'til': 1, 'may': 1, 'now': 1, 'number': 1, 'in': 1, 'the': 1, 'dozens': 1, '.': 1}
#
# **************************************************
#
# FALSE prediction FOR negative (prediction = positive):
#  {'it': 1, "'": 1, 's': 1, 'not': 1, 'a': 1, 'real': 1, 'wednesday': 1, 'morning': 1, 'if': 1, 'there': 1, 'isnt': 1, 'guy': 1, 'at': 1, 'the': 1, 'trolley': 1, 'stop': 1, 'throwing': 1, 'up': 1, 'into': 1, 'creek': 1, '...': 1, 'margarita': 1, 'day': 1, 'got': 1, 'em': 1}
#
# **************************************************
#
# FALSE prediction FOR positive (prediction = negative):
#  {'what': 1, "'": 1, 's': 1, 'the': 1, 'best': 1, 'way': 1, 'to': 1, 'get': 1, 'audio': 1, 'recordings': 1, 'from': 1, 'a': 1, '3rd': 1, 'party': 1, 'app': 1, 'off': 1, 'of': 1, 'an': 1, 'ios': 1, 'device': 1, '?': 1, 'jailbreaking': 1, 'isn': 1, 't': 1, 'option': 1, '.': 1}
#
# **************************************************
#
# FALSE prediction FOR positive (prediction = negative):
#  {'walking': 1, 'through': 1, 'chelsea': 1, 'at': 1, 'this': 1, 'time': 1, 'of': 1, 'day': 1, 'is': 1, 'rather': 1, 'lovely': 1, '.': 1, 'love': 1, 'london': 1, 'night': 1, ':': 1, 'd': 1}
#
# **************************************************
#
# FALSE prediction FOR positive (prediction = negative):
#  {'my': 1, '4': 1, 'day': 1, 'weekend': 1, '=': 1, 'binge': 1, 'watching': 1, 'old': 1, 'episodes': 1, 'of': 1, 'saturday': 1, 'night': 1, 'live': 1, 'on': 1, 'netflix': 1}
#
# **************************************************
#
# FALSE prediction FOR positive (prediction = negative):
#  {'my': 1, 'cousin': 1, 'snapchatted': 1, 'me': 1, '"': 1, 'ant-man': 1, 'tomorrow': 1, '.': 1, 'you': 1, 'good': 1, '?"': 1, 'and': 1, 'these': 1, 'are': 1, 'the': 1, 'reasons': 1, 'we': 1, 'get': 1, 'along': 1, 'so': 1, 'well': 1}
#
# **************************************************
#
# FALSE prediction FOR negative (prediction = positive):
#  {'niall': 1, 'is': 1, 'sick': 1, 'so': 1, 'he': 1, 'may': 1, 'not': 1, 'be': 1, 'out': 1, 'a': 1, 'lot': 1, '.': 1, '-a': 1}
#
# **************************************************
#
# FALSE prediction FOR negative (prediction = positive):
#  {'@exxonmobil': 1, 'gender': 1, 'doesn': 1, "'": 1, 't': 1, 'release': 1, 'ur': 1, 'responsibility': 1, 'to': 1, 'earth': 1, '!': 1, 'fossil': 1, 'fuels': 1, 'are': 1, 'killing': 1, 'little': 1, 'girls': 1, 'everywhere': 1, 'use': 1, '$': 1, 'for': 1, 'green': 1, 'industry': 1}
#
# **************************************************
#
# FALSE prediction FOR negative (prediction = positive):
#  {'@jihadwatchrs': 1, '@vanjones68': 1, 'preaches': 1, 'about': 1, 'moral': 1, 'high': 1, 'ground': 1, 'while': 1, '@potus': 1, 'executes': 1, 'drone': 1, 'strikes': 1, 'globally': 1, ',': 1, '#collateraldamage': 1, '#radicalization': 1}
#
# **************************************************
#
# FALSE prediction FOR negative (prediction = positive):
#  {'lakers': 1, 'notebook': 1, ':': 1, 'nash': 1, 'listed': 1, 'as': 1, 'doubtful': 1, 'for': 1, 'showdown': 1, 'with': 1, 'clippers': 1, 'steve': 1, 'and': 1, 'kobe': 1, 'bryant': 1, 'sat': 1, 'out': 1, '...': 1, 'http': 1, '://t': 1, '.': 1, 'co/aelumtsd': 1, '#lakers': 1}
#
# **************************************************
#
# FALSE prediction FOR positive (prediction = negative):
#  {'@skysportstennis': 1, 'the': 1, 'later': 1, 'i': 1, 'stay': 1, 'up': 1, 'better': 1, '...': 1, 'c': 1, "'": 1, 'mon': 1, 'murray': 1, '!': 1}
#
# **************************************************
#
# FALSE prediction FOR positive (prediction = negative):
#  {'happy': 1, '2nd': 1, 'birthday': 1, 'to': 1, 'prince': 1, 'george': 1, '.': 1, 'i': 1, 'can': 1, "'": 1, 't': 1, 'believe': 1, 'that': 1, 'it': 1, 's': 1, '2': 1, 'years': 1, 'since': 1, 'was': 1, 'glued': 1, 'the': 1, 'tv': 1, 'awaiting': 1, 'announcement': 1, '!': 1}
#
# **************************************************
#
# FALSE prediction FOR negative (prediction = positive):
#  {'sorry': 1, 'i': 1, 'can': 1, "'": 1, 't': 1, 'make': 1, 'it': 1, 'in': 1, 'to': 1, 'work': 1, 'tomorrow': 1, 'got': 1, 'caught': 1, 'a': 1, 'sharknado': 1}
#
# **************************************************
#
# FALSE prediction FOR positive (prediction = negative):
#  {'i': 1, "'": 1, 'm': 1, 'in': 1, 'the': 1, 'bathroom': 1, 'bumping': 1, '\\""': 1, 'niggas': 1, 'paris\\""': 1, 'crunk': 1, 'ass': 1, 'hell': 1, 'like': 1, 'it': 1, 's': 1, 'my': 1, '1st': 1, 'time': 1, 'hearing': 1, 'this': 1, 'song': 1, 'will': 1, 'never': 1, 'get': 1, 'old': 1, 'lol': 1}
#
# **************************************************
#
# FALSE prediction FOR positive (prediction = negative):
#  {'@hillaryclinton': 1, '@childdefender': 1, '"': 1, 'but': 1, 'we': 1, 'can': 1, 'now': 1, '."': 1, 'one': 1, '4': 1, 'u': 1, '<3': 1, '#stillwithher': 1, '#thepeoplespresident': 1, 'my': 1, 'president': 1, '.': 1, 'not': 1, 'quitting': 1, 'yet': 1}
#
# **************************************************
#
# FALSE prediction FOR negative (prediction = positive):
#  {'boehner': 1, 'wants': 1, 'obama': 1, 'to': 1, 'move': 1, 'his': 1, 'speech': 1, 'on': 1, 'wed': 1, 'thurs': 1, 'of': 1, 'nxt': 1, 'week': 1, ',': 1, 'due': 1, 'the': 1, 'gop': 1, 'debate': 1, '.': 1, 'no': 1, 'sense': 1, 'urgency': 1, 'while': 1, 'americans': 1, 'suffer': 1}
#
# **************************************************
#
# FALSE prediction FOR negative (prediction = positive):
#  {'@timesofindia': 1, 'it': 1, 'was': 1, 'deplorable': 1, 'to': 1, 'say': 1, 'the': 1, 'least': 1, 'of': 1, 'you': 1, 'dedicate': 1, 'almost': 1, '3': 1, 'pages': 1, 'yakub': 1, '&amp': 1, ';': 1, 'ironically': 1, 'mr': 1, '.': 1, 'kalam': 1, 'on': 1, '5th': 1, 'page': 1, 'sad': 1, 'day': 1}
# ...
#
# **************************************************
#
# FALSE prediction FOR negative (prediction = positive):
#  {'hmmm': 1, 'the': 1, 'pope': 1, 'may': 1, 'have': 1, 'pushed': 1, 'it': 1, 'too': 1, 'far': 1, 'this': 1, 'time': 1, '...........': 1}
#
# **************************************************
#
# FALSE prediction FOR negative (prediction = positive):
#  {'fuck': 1, 'the': 1, 'eu': 1, 'out': 1, 'of': 1, 'existance': 1, '#brexit': 1, '#italexit': 1, 'https': 1, '://t': 1, '.': 1, 'co/v5fbp5luqy': 1}
#
# **************************************************
#
# FALSE prediction FOR negative (prediction = positive):
#  {'nah': 1, '.': 1, '1st': 1, 'hulk': 1, 'hogan': 1, 'is': 1, 'an': 1, 'open': 1, 'bigot': 1, ',': 1, '2nd': 1, 'meek': 1, 'mill': 1, 'trashed': 1, 'the': 1, 'undertaker': 1, 'music': 1, 'and': 1, 'now': 1, 'another': 1, 'legend': 1, 'has': 1, 'died': 1, 'https': 1, '://t': 1, 'co/i9c3zibbwa': 1}
#
# **************************************************
#
# FALSE prediction FOR positive (prediction = negative):
#  {'it': 1, 'better': 1, 'be': 1, 'wednesday': 1, 'today': 1, '.': 1, 'got': 1, 'my': 1, 'slurpee': 1, 'and': 1, 'all': 1, 'i': 1, 'want': 1, 'to': 1, 'do': 1, 'is': 1, 'relax': 1, 'watching': 1, 'big': 1, 'brother': 1}
#
# **************************************************
#
# FALSE prediction FOR positive (prediction = negative):
#  {'it': 1, "'": 1, 's': 1, 'friday': 1, ',': 1, 'the': 1, 'sun': 1, 'is': 1, 'shining': 1, 'here': 1, 'in': 1, 'newport': 1, 'we': 1, 'have': 1, 'a': 1, 'long': 1, 'weekend': 1, 'ahead': 1, 'and': 1, 'tom': 1, 'brady': 1, 'will': 1, 'be': 1, 'on': 1, 'field': 1, '...': 1, 'http': 1, '://t': 1, '.': 1, 'co/tfmrlvosep': 1}
#
# **************************************************
#
# FALSE prediction FOR positive (prediction = negative):
#  {'so': 1, '..': 1, 'finally': 1, 'saw': 1, '@annaakana': 1, 'in': 1, 'ant-man': 1, ',': 1, 'i': 1, 'thin': 1, 'may': 1, 'have': 1, 'zoned': 1, 'out': 1, 'starin': 1, 'at': 1, 'her': 1, 'tho': 1, 'cuz': 1, 'remember': 1, 'nothing': 1, 'the': 1, 'guy': 1, 'said': 1, 'except': 1, '"': 1, 'yes': 1}
#
# **************************************************
#
# FALSE prediction FOR negative (prediction = positive):
#  {'@memnosoncos': 1, 'and': 1, 'looking': 1, 'at': 1, 'what': 1, 'homeopathy': 1, 'is': 1, 'should': 1, 'be': 1, 'enough': 1, 'to': 1, 'dismiss': 1, 'it': 1, 'out': 1, 'of': 1, 'hand': 1, '.': 1, 'chemistry': 1, 'just': 1, 'does': 1, 'not': 1, 'work': 1, 'the': 1, 'way': 1, 'they': 1, 'claim': 1}
#
# **************************************************
#
# FALSE prediction FOR positive (prediction = negative):
#  {'i': 1, 'don': 1, "'": 1, 't': 1, 'care': 1, 'if': 1, 'april': 1, 'is': 1, 'dead': 1, 'or': 1, 'alive': 1, ',': 1, 'just': 1, 'can': 1, 'wait': 1, 'for': 1, 'sharknado': 1, '4': 1}
#
# **************************************************
#
# FALSE prediction FOR negative (prediction = positive):
#  {'i': 1, "'": 1, 'm': 1, 'pisseeedddd': 1, 'that': 1, 'missed': 1, 'kid': 1, 'cudi': 1, 's': 1, 'show': 1, 'in': 1, 'dallas': 1, ',': 1, 'it': 1, 'was': 1, 'trending': 1, 'worldwide': 1, 'night': 1, '&all': 1, 'im': 1, 'hearing': 1, 'is': 1, 'positive': 1, 'reviews': 1, 'of': 1, 'lolla': 1}
#
# **************************************************
#
# FALSE prediction FOR negative (prediction = positive):
#  {'if': 1, 'price': 1, 'fights': 1, 'either': 1, 'klitschko': 1, ',': 1, 'they': 1, "'": 1, 'll': 1, 'definitely': 1, 'not': 1, 'want': 1, 'him': 1, 'wearing': 1, '10': 1, 'ouncers': 1, '.': 1, 'may': 1, 'as': 1, 'well': 1, 'be': 1, 'bare': 1, 'knuckle': 1, '#price': 1}
#
# **************************************************
#
# FALSE prediction FOR positive (prediction = negative):
#  {'does': 1, 'it': 1, 'really': 1, 'have': 1, 'ipad': 1, 'pro': 1, '&amp': 1, ';': 1, 'stylus': 1, ',': 1, 'tomorrow': 1, 'will': 1, 'answer': 1, '!!!': 1}
#
# **************************************************
#
# FALSE prediction FOR negative (prediction = positive):
#  {'it': 1, "'": 1, 's': 1, 'possible': 1, 'sarah': 1, 'palin': 1, 'may': 1, 'be': 1, 'more': 1, 'of': 1, 'a': 1, 'moron': 1, 'than': 1, 'trump': 1, '..': 1, 'they': 1, 'said': 1, 'was': 1, 'impossible': 1}
#
# **************************************************
#
# FALSE prediction FOR negative (prediction = positive):
#  {'i': 1, 'swear': 1, 'to': 1, 'god': 1, 'if': 1, 'miss': 1, 'chris': 1, 'brown': 1, 'this': 1, 'thursday': 1, ',': 1, "'": 1, 'm': 1, 'going': 1, 'be': 1, 'so': 1, 'mad': 1, 'at': 1, 'the': 1, 'whole': 1, 'entire': 1, 'world': 1, '&amp': 1, ';': 1, 'idgaf': 1, '.': 1}
#
# **************************************************
#
# FALSE prediction FOR negative (prediction = positive):
#  {'ok': 1, ',': 1, 'she': 1, "'": 1, 's': 1, 'against': 1, 'gay': 1, 'marriage': 1, '&amp': 1, ';': 1, 'blah': 1, 'but': 1, 'been': 1, 'married': 1, '4': 1, 'times': 1, '.': 1, 'isn': 1, 't': 1, 'divorce': 1, 'frowned': 1, 'upon': 1, 'in': 1, 'the': 1, 'bible': 1, '?': 1, 'https': 1, '://t': 1, 'co/ri8ghsuuta': 1}
#
# **************************************************
#
# FALSE prediction FOR negative (prediction = positive):
#  {'can': 1, "'": 1, 't': 1, 'sleep': 1, '...': 1, 'watching': 1, 'stevie': 1, 'tv': 1, 'for': 1, 'the': 1, '4th': 1, 'time': 1, 'tonight': 1, '@stevieryan': 1}
#
# **************************************************
#
# FALSE prediction FOR negative (prediction = positive):
#  {'this': 1, 'weekend': 1, 'on': 1, 'the': 1, 'fair': 1, '&amp': 1, ';': 1, 'balanced': 1, 'network': 1, ',': 1, 'fox': 1, 'news': 1, 'sunday': 1, "'": 1, 's': 1, 'guests': 1, 'are': 1, 'crazy': 1, 'conservative': 1, 'rick': 1, 'perry': 1, 'and': 1, 'nutty': 1, 'john': 1, 'kasich': 1, '.': 1}
#
# **************************************************
#
# FALSE prediction FOR positive (prediction = negative):
#  {'ahhhhh': 1, 'i': 1, "'": 1, 'm': 1, 'getting': 1, 'a': 1, 'turntable': 1, 'tomorrow': 1, '!': 1, 'shouts': 1, 'to': 1, 'amazon': 1, 'prime': 1, 'one': 1, 'day': 1, 'shipping': 1}
#
# **************************************************
#
# FALSE prediction FOR negative (prediction = positive):
#  {'@crampell': 1, '@tripgabriel': 1, '@nytimes': 1, 'moving': 1, '10': 1, ',': 1, '000': 1, 'to': 1, 'medicaid': 1, 'welfare': 1, 'ain': 1, "'": 1, 't': 1, 'healthcare': 1, 'reform': 1, ';': 1, 'it': 1, 's': 1, 'a': 1, 'big': 1, 'lie': 1, ':': 1, 'https': 1, '://t': 1, '.': 1, 'co/phyhpvpkao': 1}
#
# **************************************************
#
# FALSE prediction FOR negative (prediction = positive):
#  {'hank': 1, 'williams': 1, '&': 1, 'whisky': 1, 'in': 1, 'an': 1, 'empty': 1, 'bar': 1, 'on': 1, 'a': 1, 'friday': 1, '.': 1, 'really': 1, '?': 1, 'i': 1, "'": 1, 'm': 1, 'that': 1, 'guy': 1, 'now': 1, 'fuck': 1, 'cute': 1, 'bartender': 1, 'but': 1, 'she': 1, 'chats': 1, 'with': 1, 'off': 1, 'duty': 1, 'one': 1}
#
# **************************************************
#
# FALSE prediction FOR negative (prediction = positive):
#  {'the': 1, 'amount': 1, 'of': 1, 'people': 1, 'on': 1, 'facebook': 1, 'sharing': 1, 'daily': 1, 'currant': 1, 'article': 1, 'about': 1, 'sarah': 1, 'palin': 1, 'is': 1, 'hilarious': 1, '.': 1, '(': 1, 'guys': 1, ',': 1, 'it': 1, "'": 1, 's': 1, 'satire': 1, 'c': 1, 'mon': 1, '.)': 1}
#
# **************************************************
#
# FALSE prediction FOR negative (prediction = positive):
#  {'the': 1, 'same': 1, 'people': 1, 'who': 1, 'kept': 1, 'harping': 1, 'about': 1, 'privilege': 1, 'are': 1, 'now': 1, 'going': 1, 'on': 1, 'how': 1, 'great': 1, 'granddad': 1, 'clem': 1, 'was': 1, 'killing': 1, 'proto-alt': 1, 'rightists': 1, 'at': 1, 'normandy': 1}
#
# **************************************************
#
# FALSE prediction FOR negative (prediction = positive):
#  {'how': 1, 'must': 1, 'deplorables': 1, 'feel': 1, 'having': 1, 'world': 1, 'leaders': 1, 'knowing': 1, 'theyre': 1, 'crazy': 1, ',': 1, 'uneducated': 1, 'manipulative': 1, 'liarswhose': 1, 'integrity': 1, '&': 1, 'ethics': 1, 'cant': 1, 'be': 1, 'trusted': 1}
#
# **************************************************
#
# FALSE prediction FOR positive (prediction = negative):
#  {'@mylittledomo': 1, 'i': 1, 'kind': 1, 'of': 1, 'tried': 1, '...': 1, 'but': 1, 'ipod': 1, 'soooo': 1, "'": 1, 'm': 1, 'just': 1, 'gonna': 1, 'sleep': 1, 'tomorrow': 1, 'or': 1, 'something': 1, ":')": 1}
#
# **************************************************
#
# FALSE prediction FOR positive (prediction = negative):
#  {'@9ratna_9': 1, 'told': 1, 'you': 1, 'because': 1, 'said': 1, '"': 1, 'generally': 1, '15': 1, 'august': 1, 'comes': 1, 'near': 1, 'eid': 1, 'week': 1, '".': 1, 'it': 1, 'happens': 1, 'for': 1, 'only': 1, '2': 1, 'years': 1, 'after': 1, 'every': 1, '30': 1, '.': 1, ':)': 1}
#
# **************************************************
#
# FALSE prediction FOR positive (prediction = negative):
#  {'@lucidagitation': 1, '||:': 1, 'yeah': 1, '.': 1, 'it': 1, 'kind': 1, 'of': 1, 'made': 1, 'me': 1, 'chuckle': 1, 'when': 1, 'she': 1, 'tried': 1, 'hitting': 1, 'on': 1, 'batman': 1, 'i': 1, 'may': 1, 'have': 1, 'to': 1, 'plan': 1, 'some': 1, 'sl': 1, "'": 1, 's': 1, 'with': 1, 'her': 1}
#
# **************************************************
#
# FALSE prediction FOR positive (prediction = negative):
#  {'rt': 1, '@sheilatweetss': 1, ':': 1, '#rungeordierun': 1, 'should': 1, 'be': 1, 'given': 1, 'a': 1, 'heros': 1, 'welcome': 1, 'at': 1, 'the': 1, 'arsenal': 1, 'game': 1, 'on': 1, 'saturday': 1, '.@nufcfans': 1, '@nufcofficial': 1}
#
# **************************************************
#
# FALSE prediction FOR negative (prediction = positive):
#  {'#breaking': 1, ':#hezbollah': 1, 'condemns': 1, 'the': 1, 'terrorist': 1, 'bombing': 1, 'that': 1, 'occurred': 1, 'in': 1, 'city': 1, 'of': 1, '#hilla': 1, ',': 1, 'south': 1, '#baghdad#mosulops#isis#daesh#pmu#pmf': 1}
#
# **************************************************
#
# FALSE prediction FOR positive (prediction = negative):
#  {'what': 1, 'a': 1, 'round': 1, 'by': 1, 'paul': 1, 'dunne': 1, ',': 1, 'good': 1, 'luck': 1, 'tomorrow': 1, 'and': 1, 'i': 1, 'hope': 1, 'you': 1, 'win': 1, 'the': 1, 'open': 1, '.': 1}
#
# **************************************************
#
# FALSE prediction FOR negative (prediction = positive):
#  {'the': 1, 'asian': 1, 'girls': 1, 'in': 1, 'swim': 1, 'suit': 1, 'section': 1, 'for': 1, 'miss': 1, 'usa': 1, 'are': 1, 'ones': 1, 'with': 1, 'worse': 1, 'bodies': 1, ',': 1, 'c': 1, "'": 1, 'mon': 1, 'now': 1, '&gt': 1, ';': 1, '_&gt': 1, '#itsmissusa': 1, '#cantyouworkoutmore': 1}
#
# **************************************************
#
# FALSE prediction FOR negative (prediction = positive):
#  {'@pritishnandy': 1, 'yakub': 1, 'arranged': 1, 'funds': 1, 'for': 1, 'the': 1, 'blast': 1, ',': 1, 'dats': 1, 'an': 1, 'equal': 1, 'crime': 1, '.': 1, 'ppl': 1, 'who': 1, 'loose': 1, 'their': 1, 'luvd': 1, 'ones': 1, 'knw': 1, 'd': 1, 'pain': 1, 'nd': 1, 'dnt': 1, 'may': 1, 'god': 1, 'giv': 1, 'dem': 1, '1': 1}
#
# **************************************************
#
# FALSE prediction FOR negative (prediction = positive):
#  {'hopeful': 1, 'this': 1, 'day': 1, 'goes': 1, 'by': 1, 'quick': 1, '.': 1, '😏': 1, '#nationalfastfoodday': 1}
#
# **************************************************
#
# FALSE prediction FOR negative (prediction = positive):
#  {'@juturna__': 1, 'well': 1, 'medicaid': 1, 'told': 1, 'mom': 1, 'i': 1, 'can': 1, "'": 1, 't': 1, 'have': 1, 'it': 1, 'nomore': 1, 'cause': 1, 'a': 1, 'job': 1, 'and': 1, 'cry': 1, 'we': 1, 'were': 1, 'like': 1, 'umm': 1, 've': 1, 'never': 1, 'had': 1, 'in': 1, 'my': 1, 'life': 1}
#
# **************************************************
#
# FALSE prediction FOR positive (prediction = negative):
#  {'good': 1, 'night': 1, 'michael': 1, 'jackson': 1, ',': 1, 'i': 1, 'do': 1, 'love': 1, 'you': 1, '.': 1, 'see': 1, 'in': 1, 'my': 1, 'dream': 1, ':*': 1}
#
# **************************************************
#
# FALSE prediction FOR negative (prediction = positive):
#  {'@marlboro2soul': 1, 'don': 1, "'": 1, 't': 1, 'curse': 1, 'the': 1, 'saviour': 1, 'of': 1, 'islam': 1, '.': 1, 'may': 1, 'is': 1, 'take': 1, 'over': 1, 'pakistan': 1, 'soon': 1, 'to': 1, 'make': 1, 'it': 1, 'pure': 1, 'sharia': 1, 'country': 1, 'https': 1, '://t': 1, 'co/k6rppajvdq': 1}
#
# **************************************************
#
# FALSE prediction FOR negative (prediction = positive):
#  {'wilt': 1, 'chamberlain': 1, 'dropped': 1, '100': 1, 'pt': 1, "'": 1, 's': 1, 'with': 1, 'no': 1, 'threes': 1, '!': 1, 'c': 1, 'mon': 1, 'son': 1}
#
# **************************************************
#
# FALSE prediction FOR negative (prediction = positive):
#  {'regardless': 1, 'of': 1, 'how': 1, '"': 1, 'courageous': 1, 'caitlyn': 1, 'jenner': 1, 'may': 1, 'be': 1, 'he': 1, 'still': 1, 'makes': 1, 'an': 1, 'ugly': 1, 'ass': 1, 'women': 1, 'lol': 1}
#
# **************************************************
#
# FALSE prediction FOR negative (prediction = positive):
#  {'@israel4911': 1, '@letha_hughes': 1, 'it': 1, 'was': 1, 'the': 1, '14th': 1, 'that': 1, 'scotus': 1, 'ruled': 1, 'being': 1, 'violated': 1, 'in': 1, 'blocking': 1, 'marriage': 1, 'equality': 1, '.': 1, 'news': 1, 'not': 1, 'your': 1, 'strong': 1, 'subject': 1}
#
# **************************************************
#
# FALSE prediction FOR negative (prediction = positive):
#  {'truth': 1, 'never': 1, 'hide': 1, 'it': 1, 'fight': 1, '4': 1, 'its': 1, 'right': 1, 'all': 1, 'mughal': 1, 'were': 1, 'cruel': 1, 'and': 1, 'islam': 1, 'is': 1, 'threat': 1, '2': 1, 'human': 1, 'kind': 1, 'https': 1, '://t': 1, '.': 1, 'co/rvazdd4jum': 1}
#
# **************************************************
#
# FALSE prediction FOR negative (prediction = positive):
#  {'austrians': 1, 'don': 1, "'": 1, 't': 1, 'have': 1, 'electoral': 1, 'college': 1, 'https': 1, '://t': 1, '.': 1, 'co/rxntuvlf5p': 1}
#
# **************************************************
#
# FALSE prediction FOR negative (prediction = positive):
#  {'@jmmaly1': 1, '@megynkelly': 1, 'not': 1, 'sure': 1, 'where': 1, 'you': 1, 'get': 1, 'all': 1, 'of': 1, 'that': 1, 'from': 1, '.': 1, 'and': 1, 'even': 1, 'some': 1, 'those': 1, 'were': 1, 'true': 1, ',': 1, 'makes': 1, 'it': 1, 'okay': 1, 'to': 1, 'send': 1, 'hateful': 1, 'tweets': 1}
#
# **************************************************
#
# FALSE prediction FOR negative (prediction = positive):
#  {'gigi': 1, 'didn': 1, "'": 1, 't': 1, 'mock': 1, 'melania': 1, 's': 1, 'accent': 1, '.': 1, 'she': 1, 'mocked': 1, 'the': 1, 'fact': 1, 'that': 1, 'can': 1, 'even': 1, 'write': 1, 'her': 1, 'own': 1, 'speech': 1}
#
# **************************************************
#
# FALSE prediction FOR negative (prediction = positive):
#  {'@niallofficial': 1, 'zayn': 1, 'left': 1, 'on': 1, 'the': 1, '25th': 1, ',': 1, 'school': 1, 'starts': 1, 'is': 1, 'just': 1, 'not': 1, 'a': 1, 'good': 1, 'day': 1}
#
# **************************************************
#
# FALSE prediction FOR positive (prediction = negative):
#  {'galaxy': 1, 'note': 1, '5': 1, ':': 1, 'samsung': 1, 'sends': 1, 'out': 1, 'invites': 1, 'for': 1, 'august': 1, '13': 1, 'unpacked': 1, 'event': 1, 'yes': 1, ',': 1, 'the': 1, 'previous': 1, 'rumors': 1, 'were': 1, '...': 1, 'http': 1, '://t': 1, '.': 1, 'co/tmbtymp3ni': 1, '#samsung': 1}
#
# **************************************************
#
# FALSE prediction FOR positive (prediction = negative):
#  {'wolfsburg': 1, 'are': 1, 'on': 1, 'fire': 1, 'today': 1, '!': 1, 'they': 1, 'may': 1, 'be': 1, 'announcing': 1, 'the': 1, 'signing': 1, 'of': 1, 'draxler': 1, ',': 1, 'praet': 1, 'who': 1, 'was': 1, 'also': 1, 'linked': 1, 'with': 1, 'juventus': 1, 'and': 1, 'dante': 1}
#
# **************************************************
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[32], line 4
#       2 # print(predicted_labels)
#       3 for index, value in enumerate(tru_label):
# ----> 4     if predicted_labels[index] != value:
#       5         print('FALSE prediction FOR {2} (prediction = {1}):\n {0}\n'.format(test_data[index][0], predicted_labels[index], value))
#       6         print('*'*50)
#
# IndexError: list index out of range

# %% [markdown]
# # Questions 5: Optimising pre-processing and feature extraction (30 marks)

# %% [markdown]
# **Note:** it is advisable to implement question 5 in a separate notebook where you further develop the pre-processing and feature extraction functions you implemented above.

# %%
# Finally, check the accuracy of your classifier by training on all the traning data
# and testing on the test set
# Will only work once all functions are complete
functions_complete = True  # set to True once you're happy with your methods for cross val
if functions_complete:
    print(test_data[0])   # have a look at the first test data instance
    classifier = train_classifier(train_data)  # train the classifier
    test_true = [t[1] for t in test_data]   # get the ground-truth labels from the data
    test_pred = predict_labels([x[0] for x in test_data], classifier)  # classify the test data to get predicted labels
    final_scores = precision_recall_fscore_support(test_true, test_pred, average='weighted') # evaluate
    print("Done training!")
    print("Precision: %f\nRecall: %f\nF Score:%f" % final_scores[:3])
